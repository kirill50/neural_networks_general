# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1l3NDxP6D3yPtIlYjpoMebjlDTkQog9jF?usp=sharing)
# 2. Практический ноутбук 1
# 3. [Практический ноутбук 2](https://colab.research.google.com/drive/1rg1C7HdNl2jDOQ5Nc2lTbFRaghTGwK5K?usp=sharing)

# %% [markdown]
# <h3><b> DeepSort </b></h3>

# %% [markdown]
# Сразу же оговоримся, что DeepSort (модель, представленная в открытом доступе) - это скорее HumanTracking (так как обучена эта сеть на людях и предназначена изначально для треккинга людей)

# %% [markdown]
# [Ссылка на DeepSort + YOLOv5](https://pythonrepo.com/repo/mikel-brostrom-Yolov5_DeepSort_Pytorch-python-deep-learning)

# %%
# Копируем репозиторий
# !git clone --recurse-submodules https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet.git

# Переходим в директорию проекта
# %cd /content/Yolov5_StrongSORT_OSNet

# Устанавливаем все необходимые зависимости
# %pip install -qr requirements.txt

# Импорт библиотек
import torch
from IPython.display import Image, clear_output  # to display images

# Очистка экрана
clear_output()

# Вывод сообщения о заврешении установки
print(f"Установка заврешена. Верисия torch: {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Установка заврешена. Верисия torch: 1.13.1+cu116 (Tesla T4)

# %%
# Скачиваем тестовое видео
# !wget -nc https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet/releases/download/v.2.0/test.avi

# Иохраним первые 5 секунд в отдельный файл
# !y | ffmpeg -ss 00:00:00 -i test.avi -t 00:00:05 -c copy out.avi
# Out:
# --2023-01-27 13:09:32--  https://github.com/mikel-brostrom/Yolov5_StrongSORT_OSNet/releases/download/v.2.0/test.avi
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://github.com/mikel-brostrom/yolov8_tracking/releases/download/v.2.0/test.avi [following]
# --2023-01-27 13:09:33--  https://github.com/mikel-brostrom/yolov8_tracking/releases/download/v.2.0/test.avi
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# запускаем inference по video
# флаг --show-vid, чтобы визуализировать отслеживание в режиме реального времени
# !python track.py --yolo-weights yolov8m.pt --reid-weights osnet_x0_25_msmt17.pt --source out.avi --save-vid
# Out:
# track: yolo_weights=[PosixPath('yolov8n.pt')], reid_weights=osnet_x0_25_msmt17.pt, tracking_method=bytetrack, tracking_config=trackers/bytetrack/configs/bytetrack.yaml, source=out.avi, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_trajectories=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...
# 100% 6.23M/6.23M [00:00<00:00, 170MB/s]
#
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# video 1/1 (1/300) /content/Yolov5_StrongSORT_OSNet/out.avi: 384x640 12 persons, 1 car, 1 motorcycle, 58.0ms
# ...

# %%
# Смотрим, где сохранился файл, в данном случае ---> Results saved to runs/track/exp
# Сжимаем видеофайл в формат, поддерживаемый Google Colab (mpeg4 (родной) -> h264 (libx264))
# !ffmpeg -i /content/Yolov5_StrongSORT_OSNet/runs/track/exp//out.mp4 -vf fps=30 -vcodec libx264 output.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# Импорт библиотек
from IPython.display import HTML
from base64 import b64encode

# Чтение видеофайла и кодирование в base64
mp4 = open('output.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
# Вывод видео в Colab'е
HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# Сеть может отслеживать любой объект, который ваша модель Yolov8 была обучена обнаруживать.

# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1l3NDxP6D3yPtIlYjpoMebjlDTkQog9jF?usp=sharing)
# 2. Практический ноутбук 1
# 3. [Практический ноутбук 2](https://colab.research.google.com/drive/1rg1C7HdNl2jDOQ5Nc2lTbFRaghTGwK5K?usp=sharing)
