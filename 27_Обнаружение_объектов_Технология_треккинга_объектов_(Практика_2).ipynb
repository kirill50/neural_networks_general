# %% [markdown]
# **Содержание темы**
#
# 1. [Теория](https://colab.research.google.com/drive/1l3NDxP6D3yPtIlYjpoMebjlDTkQog9jF?usp=sharing)
# 2. [Практический ноутбук 1](https://colab.research.google.com/drive/1PJwiHvm1aBv4nBJ8zvOYB51ZY1IbaINe?usp=sharing)
# 3. Практический ноутбук 2

# %%
# !pip install --upgrade --no-cache-dir gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...

# %%
# !sudo apt-get update
# !sudo apt-get install -y protobuf-compiler libprotobuf-dev libprotoc-dev

# !pip install numpy cython
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libprotobuf-dev is already the newest version (3.6.1.3-2ubuntu5.2).
# ...

# %%
# Скачиваем репозиторий
# !git clone https://github.com/ifzhang/ByteTrack.git

# Переходим в директорию ByteTrack
# %cd /content/ByteTrack/

# Создаем папку pretrained
# %mkdir pretrained

# Переходим в директорию pretrained
# %cd pretrained

# Скачиваем файл по id (веса)
# !gdown --id "1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5"
# Out:
# Cloning into 'ByteTrack'...
# remote: Enumerating objects: 2007, done.
# remote: Total 2007 (delta 0), reused 0 (delta 0), pack-reused 2007
# Receiving objects: 100% (2007/2007), 79.60 MiB | 39.34 MiB/s, done.
# Resolving deltas: 100% (1141/1141), done.
# /content/ByteTrack
# mkdir: cannot create directory ‘pretrained’: File exists
# /content/ByteTrack/pretrained
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1P4mY0Yyd3PPTybgZkjMYhFri88nTmJX5
# To: /content/ByteTrack/pretrained/bytetrack_x_mot17.pth.tar
# 100% 793M/793M [00:14<00:00, 54.5MB/s]

# %%
# Установка зависимостей
# !pip3 install cython
# !pip3 install 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
# !pip3 install cython_bbox

# Переходим в директорию ByteTrack
# %cd /content/ByteTrack/

# Установка зависимостей из файла requirements.txt
# !pip3 install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-6rpk2zkm
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-6rpk2zkm
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /content/ByteTrack
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# Установка трекера
# !python3 setup.py develop
# Out:
# running develop
# /usr/local/lib/python3.9/dist-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# writing yolox.egg-info/PKG-INFO
# writing dependency_links to yolox.egg-info/dependency_links.txt
# writing top-level names to yolox.egg-info/top_level.txt
# package init file 'videos/__init__.py' not found (or not a regular file)
# package init file 'deploy/__init__.py' not found (or not a regular file)
# package init file 'build/__init__.py' not found (or not a regular file)
# package init file 'YOLOX_outputs/__init__.py' not found (or not a regular file)
# package init file 'tools/__init__.py' not found (or not a regular file)
# ...

# %%
# Переходим в директорию ByteTrack
# %cd /content/ByteTrack
# Out:
# /content/ByteTrack

# %%
# Запускаем трекер
# !python3 tools/demo_track.py video -f exps/example/mot/yolox_x_mix_det.py -c pretrained/bytetrack_x_mot17.pth.tar --fp16 --fuse --save_result &> log.txt

# %%
# Поиск файлов с расширение .mp4 с помощью регулярных выражений
import re
# %cd /content/ByteTrack
with open('log.txt', 'r') as file:
    text = file.read().replace('\n', '')

m = re.search('video save_path is ./(.+?).mp4', text)
if m:
    found = '/content/ByteTrack/' + m.group(1) + ".mp4"

found
# Out:
# /content/ByteTrack
# '/content/ByteTrack/YOLOX_outputs/yolox_x_mix_det/track_vis/2023_03_17_12_19_37/palace.mp4'

# %%
# Конвертация MP4->WEBM
# %cd /content/ByteTrack
# !ffmpeg -i $found -vcodec vp9 out.webm
# Out:
# /content/ByteTrack
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
# Вывод результата
from IPython.display import HTML
from base64 import b64encode

video_path = '/content/ByteTrack/out.webm'

mp4 = open(video_path, "rb").read()
data_url = "data:video/webm;base64," + b64encode(mp4).decode()
HTML(f"""
<video width=600 controls>
      <source src="{data_url}" type="video/webm">
</video>
""")
# Out:
# <video width=600 controls>
#       <source src="data:video/webm;base64,..." type="video/webm">
# </video>

# %% [markdown]
# **Содержание темы**
# 1. [Теория](https://colab.research.google.com/drive/1l3NDxP6D3yPtIlYjpoMebjlDTkQog9jF?usp=sharing)
# 2. [Практический ноутбук 1](https://colab.research.google.com/drive/1jy7hpHeDbDflxu1XO8LedsiDs1utmH-8?usp=sharing)
# 3. Практический ноутбук 2
