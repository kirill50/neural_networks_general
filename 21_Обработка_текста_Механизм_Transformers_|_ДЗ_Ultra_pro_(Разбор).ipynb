# %% [markdown]
# ##Задание Ultra pro (Разбор)

# %% [markdown]
# Взяв за основу практический ноутбук занятия, постройте трансформер для задачи question answering. Трансформер должен на вход принимать какой-то вопрос, а на выходе генерировать ответ на этот вопрос. Можно использовать любую базу для задачи question answering из tensorflow_datasets, например 'web_questions'.

# %% [markdown]
# ##Импорт библиотек

# %%
# Библиотека датасетов от tensorfolw
import tensorflow_datasets as tfds 

# Библиотека для обучения НС
import tensorflow as tf 

# Модуль отвечает за время и обработку временнЫх переменных
import time 

# Библиотека для работы с массивами
import numpy as np 

# Библиотека для отрисовки графиков и картинок
import matplotlib.pyplot as plt

# %% [markdown]
# ##Загрузка базы

# %%
examples, metadata = tfds.load('web_questions', # Имя датасета
                               with_info=True)  # Вывод информации

# Разделяем на обучающую и тестовую выборки
train_examples, val_examples = examples['train'], examples['test']
# Out:
# Downloading and preparing dataset web_questions/1.0.0 (download: 1.21 MiB, generated: 983.88 KiB, total: 2.17 MiB) to /root/tensorflow_datasets/web_questions/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/web_questions/1.0.0.incompleteMFT5A6/web_questions-train.tfrecord
#   0%|          | 0/3778 [00:00<?, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Shuffling and writing examples to /root/tensorflow_datasets/web_questions/1.0.0.incompleteMFT5A6/web_questions-test.tfrecord
#   0%|          | 0/2032 [00:00<?, ? examples/s]
# Dataset web_questions downloaded and prepared to /root/tensorflow_datasets/web_questions/1.0.0. Subsequent calls will reuse this data.

# %%
# Посмотрим информацию о датасете
metadata
# Out:
# tfds.core.DatasetInfo(
#     name='web_questions',
#     version=1.0.0,
#     description='This dataset consists of 6,642 question/answer pairs.
# The questions are supposed to be answerable by Freebase, a large knowledge graph.
# The questions are mostly centered around a single named entity.
# The questions are popular ones asked on the web (at least in 2013).',
#     homepage='https://worksheets.codalab.org/worksheets/0xba659fe363cb46e7a505c5b6a774dc8a',
#     features=FeaturesDict({
#         'answers': Sequence(Text(shape=(), dtype=tf.string)),
#         'question': Text(shape=(), dtype=tf.string),
#         'url': Text(shape=(), dtype=tf.string),
#     }),
#     total_num_examples=5810,
#     splits={
#         'test': 2032,
#         'train': 3778,
#     },
#     supervised_keys=None,
#     citation="""@inproceedings{berant-etal-2013-semantic,
#         title = "Semantic Parsing on {F}reebase from Question-Answer Pairs",
#         author = "Berant, Jonathan  and
#           Chou, Andrew  and
#           Frostig, Roy  and
#           Liang, Percy",
#         booktitle = "Proceedings of the 2013 Conference on Empirical Methods in Natural Language Processing",
#         month = oct,
#         year = "2013",
#         address = "Seattle, Washington, USA",
#         publisher = "Association for Computational Linguistics",
#         url = "https://www.aclweb.org/anthology/D13-1160",
#         pages = "1533--1544",
#     }""",
#     redistribution_info=,
# )

# %%
# Посмотрим на структуру данных
for full in train_examples.take(5):
  print(full)
# Out:
# {'answers': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'Joe Flacco'], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'who is the ravens quarterback 2012?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/baltimore_ravens'>}
# {'answers': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'Whig Party'], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'what political party was henry clay?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/henry_clay'>}
# {'answers': <tf.Tensor: shape=(1,), dtype=string, numpy=array([b'UTC+07:00'], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'where to stay in thailand koh samui?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/ko_samui'>}
# {'answers': <tf.Tensor: shape=(10,), dtype=string, numpy=
# array([b'Bahrain', b'Afghanistan', b'Bangladesh', b'Bhutan', b'Brunei',
#        b'Indonesia', b'India', b'Cambodia', b'China', b'Iraq'],
#       dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'what countries are included in the continent of asia?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/asia'>}
# {'answers': <tf.Tensor: shape=(10,), dtype=string, numpy=
# array([b'Murder Was the Case', b'Above the Rim', b'Bullet',
#        b'Gang Related', b'Watch Juice',
#        b'Tupac: Live at the House of Blues', b'Nothing but Trouble',
#        b'Juice', b'Poetic Justice', b"Gridlock'd"], dtype=object)>, 'question': <tf.Tensor: shape=(), dtype=string, numpy=b'what movies does tupac act in?'>, 'url': <tf.Tensor: shape=(), dtype=string, numpy=b'http://www.freebase.com/view/en/tupac_shakur'>}

# %% [markdown]
# Можно заметить, что на некоторые вопросы в данных существует более одного ответа.

# %%
# Выведем 10 пар вопрос-ответ (только первый ответ, если их несколько)
for full in train_examples.take(10):

  # Чтобы вывести текст в читаемом формате, нужно перевести его в кодировку UTF-8
  print('Вопрос: ', str(full['question'].numpy(), encoding='UTF-8'))
  print('Ответ : ', str(full['answers'].numpy()[0], encoding='UTF-8'))
  print()
# Out:
# Вопрос:  who is the ravens quarterback 2012?
# Ответ :  Joe Flacco
#
# Вопрос:  what political party was henry clay?
# Ответ :  Whig Party
#
# Вопрос:  where to stay in thailand koh samui?
# Ответ :  UTC+07:00
#
# Вопрос:  what countries are included in the continent of asia?
# Ответ :  Bahrain
#
# Вопрос:  what movies does tupac act in?
# Ответ :  Murder Was the Case
#
# Вопрос:  what did martin luther king jr go to college for?
# Ответ :  Sociology
#
# Вопрос:  where did jennifer hudson go to school?
# Ответ :  Dunbar Vocational High School
#
# Вопрос:  where is danish located?
# Ответ :  Denmark
#
# Вопрос:  when did barry zito won the cy young?
# Ответ :  2002 Major League Baseball Season
#
# Вопрос:  what language do fiji people speak?
# Ответ :  Fiji Hindi

# %% [markdown]
# В токенайзер отправим только тексты вопросов. Есть ли смысл отправлять в него тексты ответов вопрос резонный, ведь каждая пара вопрос/ответ уникальны, а следовательно и ответы одних не подойдут другим. Мы попробуем такой способ токенизации.

# %%
# Токенайзер, с размером словаря 2**13
tokenizer_all = tfds.deprecated.text.SubwordTextEncoder.build_from_corpus(
    (str(full['question'].numpy(), encoding='UTF-8') for full in train_examples), target_vocab_size=2**13)

# %%
# Размер словаря
tokenizer_all.vocab_size
# Out:
# 4513

# %%
# Выведем 1 вопрос в формате индексов
for full in train_examples.take(1):
  print(tokenizer_all.encode(str(full['question'].numpy(), encoding='UTF-8')))
# Out:
# [5, 3, 2, 398, 1384, 62, 4320]

# %%
# QUE и ANS это вопросы и ответы
def encode(que, ans):

  # Добавление токенов start и end в текст вопроса
  QUE = [tokenizer_all.vocab_size] + tokenizer_all.encode(
      str(que.numpy(), encoding='UTF-8')) + [tokenizer_all.vocab_size+1]
  
  # Добавление токенов start и end в текст ответа
  ANS = [tokenizer_all.vocab_size] + tokenizer_all.encode(
      str(ans.numpy()[0], encoding='UTF-8')) + [tokenizer_all.vocab_size+1]
  
  return QUE, ANS

# %%
# Обертка над предыдущей функцией encode()
def tf_encode(full):
  a=full
  question, answer = tf.py_function(encode,            # Функция
                                    [full['question'], # Аргументы 
                                     full['answers']], 
                                    [tf.int64,         # Типы данных
                                     tf.int64]) 
  question.set_shape([None])
  answer.set_shape([None])

  return question, answer

# %%
# Размер буфера в памяти при подготовке датасета
BUFFER_SIZE = 20000 

# Размер батча
BATCH_SIZE = 64  

# Максимальная длина фраз
MAX_LENGTH = 30

# %%
def filter_max_length(x, y, max_length=MAX_LENGTH):
    
  return tf.logical_and(tf.size(x) <= max_length, # Маска для значений x
                        tf.size(y) <= max_length) # Маска для значений y

# %%
# Прогоняем тексты через токенайзер
train_dataset = train_examples.map(tf_encode) 

# Убираем длинные фразы
train_dataset = train_dataset.filter(filter_max_length) 

# Грузим в память
train_dataset = train_dataset.cache() 

# Делим на батчи и перемешиваем
train_dataset = train_dataset.shuffle(BUFFER_SIZE).padded_batch(BATCH_SIZE) 

# Кешируем датасет (это делается для увеличения скорости обучения сети)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE) 

# Преобразуем в формат map
val_dataset = val_examples.map(tf_encode)

# Фильтруем по максимальной длинне
val_dataset = val_dataset.filter(filter_max_length).padded_batch(BATCH_SIZE)

# %%
# Возьмем первый батч датасета
questions_batch, answers_batch = next(iter(val_dataset))

# Посмотрим что внутри
questions_batch, answers_batch
# Out:
# (<tf.Tensor: shape=(64, 24), dtype=int64, numpy=
#  array([[4513,    1,   40, ...,    0,    0,    0],
#         [4513,    5,  311, ...,    0,    0,    0],
#         [4513,    5,  255, ...,    0,    0,    0],
#         ...,
#         [4513,    5,    3, ...,    0,    0,    0],
#         [4513,    1,    3, ...,    0,    0,    0],
#         [4513,    1,   37, ...,    0,    0,    0]])>,
#  <tf.Tensor: shape=(64, 29), dtype=int64, numpy=
#  array([[4513, 4229, 4335, ...,    0,    0,    0],
#         [4513, 4340, 4354, ...,    0,    0,    0],
#         [4513, 4322, 4372, ...,    0,    0,    0],
#         ...,
#         [4513, 4341, 4368, ...,    0,    0,    0],
#         [4513, 4323,  303, ...,    0,    0,    0],
#         [4513, 4322, 4367, ...,    0,    0,    0]])>)

# %%
def get_angles(pos, i, d_model):

  # По формуле рассчитаем аргументы позиционного кодирования
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  
  # Получаем аргументы
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # Чётные индексы будут принимать значение от sin
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # Нечётные индексы будут принимать значение от cos
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  # Добавляем ещё одну размерность
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
# Зададим значения 50, 512
pos_encoding = positional_encoding(50, 512)
print(pos_encoding.shape)

# Выведем значения поз. кодирования в виде heatmap
plt.pcolormesh(pos_encoding[0], cmap='RdBu')
plt.xlabel('Depth')
plt.xlim((0, 512))
plt.ylabel('Position')
plt.colorbar()
plt.show()
# Out:
# (1, 50, 512)

# %% [markdown]
# ##Создание архитектуры трансформера

# %% [markdown]
# Архитектура трансформера стандартная, как на занятии. Мы так же работаем с последовательностями, только раньше мы делали перевод и последовательность португальских слов переводили в последовательность русских, а теперь мы работаем с последовательностями одного языка - вопросами и ответами.

# %%
class MultiHeadAttention(tf.keras.layers.Layer):

  def __init__(self, 
               d_model = 512, # Максимальная длина предложения
               num_heads = 8, # Количество голов сети
               causal=False,  # Параметр для слоя Attention
               dropout=0.0):  # Значение Dropout

    super(MultiHeadAttention, self).__init__()  # Здесь все головы считаем паралелльно - поэтому attention пробегает и по батчу и по числу голов

    assert d_model % num_heads == 0 # Проверим, что размерность головы - целое цисло
    depth = d_model // num_heads    # Размерность каждой головы внимания  =>>  multi-headed_depth = depth / num_heads
                                    # Заметим, что выходы голов конкатенируются, поэтому их размер в их число раз меньше.
                                    # Поэтому размерность выхода должно совпасть в размерностью входа

    self.w_query = tf.keras.layers.Dense(d_model)                            # Dense для Query  (batch_size , seq_length, depth) 
    self.split_reshape_query = tf.keras.layers.Reshape((-1,num_heads,depth)) # Слой для решейпа query до (batch_size , seq_length, num_heads, multi_headed_depth)  
    self.split_permute_query = tf.keras.layers.Permute((2,1,3))              # Слой для перестановки размерностей для использования Attention

    self.w_value = tf.keras.layers.Dense(d_model)                            # Dense для Value  (batch_size , seq_length, depth)
    self.split_reshape_value = tf.keras.layers.Reshape((-1,num_heads,depth)) # Слой для решейпа value до (batch_size , seq_length, num_heads, multi_headed_depth
    self.split_permute_value = tf.keras.layers.Permute((2,1,3))              # Слой для перестановки размерностей для использования Attention

    self.w_key = tf.keras.layers.Dense(d_model)                              # Dense для Key  (batch_size , seq_length, depth)
    self.split_reshape_key = tf.keras.layers.Reshape((-1,num_heads,depth))   # Слой для решейпа key до (batch_size , seq_length, num_heads, multi_headed_depth
    self.split_permute_key = tf.keras.layers.Permute((2,1,3))                # Слой для перестановки размерностей для использования Attention

    self.attention = tf.keras.layers.Attention(causal=causal, dropout=dropout) # Прописываем слой Attention
    self.join_permute_attention = tf.keras.layers.Permute((2,1,3))             # Слой обратной перестановки размерностей
    self.join_reshape_attention = tf.keras.layers.Reshape((-1,d_model))        # Слой обратного решейпа до размернсти модели

    self.dense = tf.keras.layers.Dense(d_model)     # Полносвязный слой

  def call(self, inputs, mask=None, training=None): # Основная рабочая функция

    q = inputs[0]                           # Вытащим входной вектор Query
    v = inputs[1]                           # Вытащим входной вектор Value
    k = inputs[2] if len(inputs) > 2 else v # Вытащим входной вектор Key

    query = self.w_query(q)                   # Прогоним через dense
    query = self.split_reshape_query(query)   # Решейпим
    query = self.split_permute_query(query)   # Переставляем размерность

    value = self.w_value(v)                 # Прогоним через dense
    value = self.split_reshape_value(value) # Решейпим
    value = self.split_permute_value(value) # Переставляем размерность

    key = self.w_key(k)               # Прогоним через dense
    key = self.split_reshape_key(key) # Решейпим
    key = self.split_permute_key(key) # Переставляем размерность

    if mask is not None: # Применим маску если есть 

      if mask[0] is not None:
        mask[0] = tf.keras.layers.Reshape((-1,1))(mask[0])     # Слой для решейпа
        mask[0] = tf.keras.layers.Permute((2,1))(mask[0])      # Слой для перестановки размерностей
      
      if mask[1] is not None:
        mask[1] = tf.keras.layers.Reshape((-1,1))(mask[1])     # Слой для решейпа
        mask[1] = tf.keras.layers.Permute((2,1))(mask[1])      # Слой для перестановки размерностей

    attention = self.attention([query, value, key], mask=mask) # Вычисляем вектор внимания
    attention = self.join_permute_attention(attention)         # Обратно перемешиваем размерности
    attention = self.join_reshape_attention(attention)         # Решейпим до (batch_size , seq_length, depth) 

    x = self.dense(attention) # Выходной dense

    return x

# %%
class EncoderLayer(tf.keras.layers.Layer): 

  def __init__(self,  
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout
    
    super(EncoderLayer, self).__init__()

    self.multi_head_attention = MultiHeadAttention(d_model, num_heads)   # Определим слой  MultiHeadAttention
    self.dropout_attention = tf.keras.layers.Dropout(dropout)            # Добавим дропаут
    self.add_attention = tf.keras.layers.Add()                           # Слой для получения resudial связи
    self.layer_norm_attention = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')               # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                              # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                     # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                    # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)  # Слой нормализации

  def call(self, inputs, mask=None, training=None):

    # Входной вектор input размножим до 3 - это query, value, key и отдадим attenton, с маской если есть 
    attention = self.multi_head_attention([inputs,inputs,inputs], mask = [mask,mask]) 
    
    # Уменьшим переобучение дроаутом
    attention = self.dropout_attention(attention, training = training) 
    
    # Сделаем resudial связь - добавим входной вектор
    x = self.add_attention([inputs , attention]) 
    
    # Далее нормализация в масштабах уровня
    x = self.layer_norm_attention(x)  
    # x = inputs

    # Добавим Feed Forward  
    
    # Проходим 1й dense с активашкой relu
    dense = self.dense1(x) 
    
    # Второй dense без активашки т.е. с линейной активационной функцией
    dense = self.dense2(dense)  
    
    # Добавляем дропаут
    dense = self.dropout_dense(dense, training = training)  
    
    # Еще одна resudial связь
    x = self.add_dense([x , dense])  
    
    # Нормализация в масштабах уровня
    x = self.layer_norm_dense(x)  

    return x

# %%
class DecoderLayer(tf.keras.layers.Layer):

  def __init__(self,  
               d_model = 512,  # Максимальная длина предложения
               num_heads = 8,  # Количество голов сети
               dff = 2048,     # Количество нейронов первого Dense слоя
               dropout = 0.0): # Значение Dropout

    super(DecoderLayer, self).__init__()

    self.multi_head_attention1 =  MultiHeadAttention(d_model, num_heads, causal = True) # Определим слой  MultiHeadAttention
    self.dropout_attention1 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention1 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации

    self.multi_head_attention2 =  MultiHeadAttention(d_model, num_heads)                # Определим слой  MultiHeadAttention 
    self.dropout_attention2 = tf.keras.layers.Dropout(dropout)                          # Добавим дропаут
    self.add_attention2 = tf.keras.layers.Add()                                         # Слой для получения resudial связи
    self.layer_norm_attention2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)       # Слой нормализации


    self.dense1 = tf.keras.layers.Dense(dff, activation='relu')                         # Первый dense в Feed Forward
    self.dense2 = tf.keras.layers.Dense(d_model)                                        # Второй  dense в Feed Forward
    self.dropout_dense = tf.keras.layers.Dropout(dropout)                               # Добавим дропаут
    self.add_dense = tf.keras.layers.Add()                                              # Слой для получения resudial связи
    self.layer_norm_dense = tf.keras.layers.LayerNormalization(epsilon=1e-6)            # Слой нормализации

  def call(self, inputs, mask=None, training=None):
    
    # Подадим на multi-head attention  Query, Key, Value вектора - здесь это один и тотже вектор
    attention = self.multi_head_attention1([inputs[0],inputs[0],inputs[0]], mask = [mask[0],mask[0]])
    
    # Пробежим дропаут
    attention = self.dropout_attention1(attention, training = training)
    
    # Пробросим Resudial-связь
    x = self.add_attention1([inputs[0] , attention])
    
    # Выполним нормализацию
    x = self.layer_norm_attention1(x)
    
    # Второй multi-head attention. Подаем выход предыдущих слоев x и выход от энкодера, маску (если есть)
    attention = self.multi_head_attention2([x, inputs[1],inputs[1]], mask = [mask[0],mask[1]])
    
    # Прогоняем через дропаут
    attention = self.dropout_attention2(attention, training = training)
    
    # Пробросим Resudial-связь
    x = self.add_attention1([x , attention])
    
    # Выполним нормализацию
    x = self.layer_norm_attention1(x)

    ## Feed Forward
    
    # 1 dense + relu
    dense = self.dense1(x)

    # 2 dense +linear
    dense = self.dense2(dense)

    # Прогоняем через дропаут
    dense = self.dropout_dense(dense, training = training)

    # Пробросим Resudial-связь
    x = self.add_dense([x , dense])

    # Выполним нормализацию
    x = self.layer_norm_dense(x)

    return x

# %%
class Encoder(tf.keras.layers.Layer):

  def __init__(self, 
               input_vocab_size,                  # Размер словаря
               num_layers = 4,                    # Количество слоев энкодера
               d_model = 512,                     # Максимальная длина предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout
    
    super(Encoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(input_vocab_size, # Пропишем слой Embedding
                                               d_model, 
                                               mask_zero=True)  
    
    self.pos = positional_encoding(maximum_position_encoding,    # Функция позиционного кодирования
                                   d_model)   
                   
    self.encoder_layers = [ EncoderLayer(d_model = d_model,      # Список Nx слоев кодера
                                         num_heads = num_heads, 
                                         dff = dff, 
                                         dropout = dropout) for _ in range(num_layers)]  

    self.dropout = tf.keras.layers.Dropout(dropout)              # Просто дропаут

  def call(self, inputs, mask=None, training=None):
    
    # Входной эмбеддинг  
    x = self.embedding(inputs) 
    
    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32)) 
    x += self.pos[: , :tf.shape(x)[1], :]
    
    # Прогоняем через дроаут
    x = self.dropout(x, training=training)

    # Входной слой embedding+ Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs)

    # Прогоним через Nx слоев кодера
    for encoder_layer in self.encoder_layers: 
      x = encoder_layer(x, mask = embedding_mask)

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs)

# %%
class Decoder(tf.keras.layers.Layer):

  def __init__(self, 
               target_vocab_size,                 # Размер словаря выходных данных
               num_layers = 4,                    # Количество слоев декодера
               d_model = 512,                     # Максимальный размер предложения
               num_heads = 8,                     # Количество голов сети
               dff = 2048,                        # Количество нейронов первого Dense слоя
               maximum_position_encoding = 10000, # Максимальное число позиций
               dropout = 0.0):                    # Значение Dropout
    
    super(Decoder, self).__init__()

    self.d_model = d_model

    self.embedding = tf.keras.layers.Embedding(target_vocab_size, # Пропишем слой Embedding
                                               d_model, 
                                               mask_zero=True) 
    
    self.pos = positional_encoding(maximum_position_encoding,     # Функция позиционного кодирования
                                   d_model)                     

    self.decoder_layers = [ DecoderLayer(d_model = d_model, 
                                         num_heads = num_heads, 
                                         dff = dff, 
                                         dropout = dropout)  for _ in range(num_layers)] # Список Nx слоев декодера 

    self.dropout = tf.keras.layers.Dropout(dropout)               # Слой дропаут

  def call(self, inputs, mask=None, training=None):
    
    # Выполним переход в эмбеддинг
    x = self.embedding(inputs[0]) 
    
    # Позиционное кодирование
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos[: , :tf.shape(x)[1], :]
    
    # Просто dropout
    x = self.dropout(x, training=training)
    
    # Входной слой embedding + Позиционное кодирование
    embedding_mask = self.embedding.compute_mask(inputs[0])

    # Прогоним через Nx слоев декодера
    for decoder_layer in self.decoder_layers:
      x = decoder_layer([x,inputs[1]], mask = [embedding_mask, mask])

    return x

  # Закомментируйте код ниже, если хотите использовать masked_loss()
  def compute_mask(self, inputs, mask=None):
    return self.embedding.compute_mask(inputs[0])

# %% [markdown]
# ##Обучение трансформера

# %%
num_layers = 4 # Количество слоев
d_model = 128  # Размерность модели
dff = 512      # Максимальная длина предложений
num_heads = 8  # Количество голов

dropout_rate = 0.1 # Значение Dropout

input_vocab_size = tokenizer_all.vocab_size + 2     # Индекс входного тега
target_vocab_size = tokenizer_all.vocab_size + 3    # Индекс выходного тега


input  = tf.keras.layers.Input(shape=(None,)) # Входной слой для переводимой фразы
target = tf.keras.layers.Input(shape=(None,)) # Вход для перевода

encoder = Encoder(input_vocab_size,           # Создаем энкодер
                  num_layers = num_layers, 
                  d_model = d_model, 
                  num_heads = num_heads, 
                  dff = dff, 
                  dropout = dropout_rate)  

decoder = Decoder(target_vocab_size,          # Создаем декодер
                  num_layers = num_layers, 
                  d_model = d_model, 
                  num_heads = num_heads, 
                  dff = dff, 
                  dropout = dropout_rate) 

# Собираем модель 
x = encoder(input)
x = decoder([target, x] , mask = encoder.compute_mask(input))
x = tf.keras.layers.Dense(target_vocab_size)(x)

# Формируем модель, выводим саммери
model = tf.keras.models.Model(inputs=[input, target], outputs=x)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  encoder (Encoder)              (None, None, 128)    1371008     ['input_1[0][0]']
#
#  tf.math.not_equal (TFOpLambda)  (None, None)        0           ['input_1[0][0]']
#
#  decoder (Decoder)              (None, None, 128)    1635328     ['input_2[0][0]',
#                                                                   'encoder[0][0]',
#                                                                   'tf.math.not_equal[0][0]']
#
#  dense_64 (Dense)               (None, None, 4516)   582564      ['decoder[0][0]']
#
# ==================================================================================================
# Total params: 3,588,900
# Trainable params: 3,588,900
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
    
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()

    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)

    self.warmup_steps = warmup_steps

  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
# Оптимайзер 
optimizer = tf.keras.optimizers.Adam(CustomSchedule(d_model), 
                                     beta_1=0.9, 
                                     beta_2=0.98, 
                                     epsilon=1e-9)
# Функция потерь
loss = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

def masked_loss(y_true, y_pred):

  # Считаем маску  
  mask = tf.math.logical_not(tf.math.equal(y_true, 0))
  _loss = loss(y_true, y_pred)

  mask = tf.cast(mask, dtype=_loss.dtype)

  # Накинем маску на потери  
  _loss *= mask

  return tf.reduce_sum(_loss)/tf.reduce_sum(mask)

metrics = [loss, masked_loss, tf.keras.metrics.SparseCategoricalAccuracy()]

model.compile(optimizer=optimizer, loss = loss, metrics = metrics)

# %%
# Количество батчей для обучения
num_batches = 0
for (batch, (_,_)) in enumerate(train_dataset):
  num_batches = batch
print(num_batches)

# Количество батчей для проверки
val_batches = 0
for (batch, (_,_)) in enumerate(val_dataset):
  val_batches = batch
print(val_batches)
# Out:
# 57
# 30

# %% [markdown]
# Обучаем:

# %%
# Создадим генератор данных для обучения
def generator(data_set):
    
  while True:
    for q_batch, a_batch in data_set:
      yield ( [q_batch , a_batch[:, :-1] ] , a_batch[:, 1:] )

# При помощи генератора запускаем обучение
history = model.fit(x = generator(train_dataset),              # Данные для обучения
                    validation_data = generator(val_dataset),  # Данные для проверки
                    epochs=200,                                # Количество эпох
                    steps_per_epoch = num_batches,             # Количество батчей
                    validation_steps = val_batches)            # Батчи на проверку
# Out:
# Epoch 1/200
# 57/57 [==============================] - 27s 175ms/step - loss: 4.0573 - sparse_categorical_crossentropy: 8.3173 - masked_loss: 8.3198 - sparse_categorical_accuracy: 0.0154 - val_loss: 3.9451 - val_sparse_categorical_crossentropy: 8.0733 - val_masked_loss: 8.0997 - val_sparse_categorical_accuracy: 0.0773
# Epoch 2/200
# 57/57 [==============================] - 6s 111ms/step - loss: 3.8395 - sparse_categorical_crossentropy: 7.8821 - masked_loss: 7.9088 - sparse_categorical_accuracy: 0.0777 - val_loss: 3.7158 - val_sparse_categorical_crossentropy: 7.6040 - val_masked_loss: 7.6353 - val_sparse_categorical_accuracy: 0.0773
# Epoch 3/200
# 57/57 [==============================] - 6s 111ms/step - loss: 3.5541 - sparse_categorical_crossentropy: 7.3481 - masked_loss: 7.3786 - sparse_categorical_accuracy: 0.0781 - val_loss: 3.4079 - val_sparse_categorical_crossentropy: 6.9738 - val_masked_loss: 7.0060 - val_sparse_categorical_accuracy: 0.0773
# Epoch 4/200
# 57/57 [==============================] - 6s 111ms/step - loss: 3.2077 - sparse_categorical_crossentropy: 6.6089 - masked_loss: 6.6434 - sparse_categorical_accuracy: 0.0779 - val_loss: 2.9975 - val_sparse_categorical_crossentropy: 6.1340 - val_masked_loss: 6.1762 - val_sparse_categorical_accuracy: 0.0773
# Epoch 5/200
# 57/57 [==============================] - 6s 111ms/step - loss: 2.8015 - sparse_categorical_crossentropy: 5.7198 - masked_loss: 5.7799 - sparse_categorical_accuracy: 0.0941 - val_loss: 2.5492 - val_sparse_categorical_crossentropy: 5.2166 - val_masked_loss: 5.3145 - val_sparse_categorical_accuracy: 0.1527
# Epoch 6/200
# 57/57 [==============================] - 6s 111ms/step - loss: 2.3948 - sparse_categorical_crossentropy: 4.8876 - masked_loss: 4.9959 - sparse_categorical_accuracy: 0.1543 - val_loss: 2.2173 - val_sparse_categorical_crossentropy: 4.5374 - val_masked_loss: 4.6663 - val_sparse_categorical_accuracy: 0.1531
# Epoch 7/200
# 57/57 [==============================] - 6s 111ms/step - loss: 2.1124 - sparse_categorical_crossentropy: 4.3361 - masked_loss: 4.4800 - sparse_categorical_accuracy: 0.1631 - val_loss: 2.0222 - val_sparse_categorical_crossentropy: 4.1381 - val_masked_loss: 4.3114 - val_sparse_categorical_accuracy: 0.1821
# Epoch 8/200
# 57/57 [==============================] - 6s 110ms/step - loss: 1.9516 - sparse_categorical_crossentropy: 4.0082 - masked_loss: 4.2017 - sparse_categorical_accuracy: 0.2002 - val_loss: 1.8779 - val_sparse_categorical_crossentropy: 3.8428 - val_masked_loss: 4.0638 - val_sparse_categorical_accuracy: 0.2139
# Epoch 9/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.8278 - sparse_categorical_crossentropy: 3.7261 - masked_loss: 3.9603 - sparse_categorical_accuracy: 0.2189 - val_loss: 1.7500 - val_sparse_categorical_crossentropy: 3.5811 - val_masked_loss: 3.8327 - val_sparse_categorical_accuracy: 0.2304
# Epoch 10/200
# 57/57 [==============================] - 10s 179ms/step - loss: 1.7108 - sparse_categorical_crossentropy: 3.4987 - masked_loss: 3.7560 - sparse_categorical_accuracy: 0.2304 - val_loss: 1.6605 - val_sparse_categorical_crossentropy: 3.3980 - val_masked_loss: 3.6592 - val_sparse_categorical_accuracy: 0.2478
# Epoch 11/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.6310 - sparse_categorical_crossentropy: 3.3437 - masked_loss: 3.6067 - sparse_categorical_accuracy: 0.2445 - val_loss: 1.5859 - val_sparse_categorical_crossentropy: 3.2453 - val_masked_loss: 3.5036 - val_sparse_categorical_accuracy: 0.2649
# Epoch 12/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.5513 - sparse_categorical_crossentropy: 3.2143 - masked_loss: 3.4740 - sparse_categorical_accuracy: 0.2623 - val_loss: 1.5337 - val_sparse_categorical_crossentropy: 3.1386 - val_masked_loss: 3.3919 - val_sparse_categorical_accuracy: 0.2822
# Epoch 13/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.5413 - sparse_categorical_crossentropy: 3.1048 - masked_loss: 3.3587 - sparse_categorical_accuracy: 0.2805 - val_loss: 1.4858 - val_sparse_categorical_crossentropy: 3.0405 - val_masked_loss: 3.2875 - val_sparse_categorical_accuracy: 0.2927
# Epoch 14/200
# 57/57 [==============================] - 6s 112ms/step - loss: 1.4582 - sparse_categorical_crossentropy: 3.0030 - masked_loss: 3.2488 - sparse_categorical_accuracy: 0.2960 - val_loss: 1.4489 - val_sparse_categorical_crossentropy: 2.9649 - val_masked_loss: 3.2067 - val_sparse_categorical_accuracy: 0.3070
# Epoch 15/200
# 57/57 [==============================] - 6s 113ms/step - loss: 1.4280 - sparse_categorical_crossentropy: 2.9193 - masked_loss: 3.1603 - sparse_categorical_accuracy: 0.3087 - val_loss: 1.4074 - val_sparse_categorical_crossentropy: 2.8801 - val_masked_loss: 3.1154 - val_sparse_categorical_accuracy: 0.3232
# Epoch 16/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.3935 - sparse_categorical_crossentropy: 2.8421 - masked_loss: 3.0744 - sparse_categorical_accuracy: 0.3203 - val_loss: 1.3793 - val_sparse_categorical_crossentropy: 2.8225 - val_masked_loss: 3.0534 - val_sparse_categorical_accuracy: 0.3299
# Epoch 17/200
# 57/57 [==============================] - 6s 110ms/step - loss: 1.3181 - sparse_categorical_crossentropy: 2.7344 - masked_loss: 2.9625 - sparse_categorical_accuracy: 0.3431 - val_loss: 1.3491 - val_sparse_categorical_crossentropy: 2.7608 - val_masked_loss: 2.9868 - val_sparse_categorical_accuracy: 0.3448
# Epoch 18/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.3055 - sparse_categorical_crossentropy: 2.6711 - masked_loss: 2.8923 - sparse_categorical_accuracy: 0.3554 - val_loss: 1.3263 - val_sparse_categorical_crossentropy: 2.7142 - val_masked_loss: 2.9364 - val_sparse_categorical_accuracy: 0.3508
# Epoch 19/200
# 57/57 [==============================] - 6s 114ms/step - loss: 1.2755 - sparse_categorical_crossentropy: 2.6048 - masked_loss: 2.8195 - sparse_categorical_accuracy: 0.3685 - val_loss: 1.3186 - val_sparse_categorical_crossentropy: 2.6984 - val_masked_loss: 2.9194 - val_sparse_categorical_accuracy: 0.3570
# Epoch 20/200
# 57/57 [==============================] - 6s 113ms/step - loss: 1.2315 - sparse_categorical_crossentropy: 2.5227 - masked_loss: 2.7310 - sparse_categorical_accuracy: 0.3850 - val_loss: 1.3015 - val_sparse_categorical_crossentropy: 2.6633 - val_masked_loss: 2.8814 - val_sparse_categorical_accuracy: 0.3687
# Epoch 21/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.2029 - sparse_categorical_crossentropy: 2.4720 - masked_loss: 2.6764 - sparse_categorical_accuracy: 0.3919 - val_loss: 1.2788 - val_sparse_categorical_crossentropy: 2.6170 - val_masked_loss: 2.8314 - val_sparse_categorical_accuracy: 0.3782
# Epoch 22/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.1609 - sparse_categorical_crossentropy: 2.3806 - masked_loss: 2.5781 - sparse_categorical_accuracy: 0.4125 - val_loss: 1.2691 - val_sparse_categorical_crossentropy: 2.5971 - val_masked_loss: 2.8099 - val_sparse_categorical_accuracy: 0.3845
# Epoch 23/200
# 57/57 [==============================] - 6s 112ms/step - loss: 1.1325 - sparse_categorical_crossentropy: 2.3373 - masked_loss: 2.5311 - sparse_categorical_accuracy: 0.4229 - val_loss: 1.2535 - val_sparse_categorical_crossentropy: 2.5651 - val_masked_loss: 2.7753 - val_sparse_categorical_accuracy: 0.3932
# Epoch 24/200
# 57/57 [==============================] - 6s 110ms/step - loss: 1.1154 - sparse_categorical_crossentropy: 2.2622 - masked_loss: 2.4471 - sparse_categorical_accuracy: 0.4357 - val_loss: 1.2574 - val_sparse_categorical_crossentropy: 2.5731 - val_masked_loss: 2.7839 - val_sparse_categorical_accuracy: 0.3942
# Epoch 25/200
# 57/57 [==============================] - 6s 112ms/step - loss: 1.0652 - sparse_categorical_crossentropy: 2.1984 - masked_loss: 2.3811 - sparse_categorical_accuracy: 0.4501 - val_loss: 1.2464 - val_sparse_categorical_crossentropy: 2.5507 - val_masked_loss: 2.7598 - val_sparse_categorical_accuracy: 0.4024
# Epoch 26/200
# 57/57 [==============================] - 6s 112ms/step - loss: 1.0307 - sparse_categorical_crossentropy: 2.1290 - masked_loss: 2.3059 - sparse_categorical_accuracy: 0.4643 - val_loss: 1.2536 - val_sparse_categorical_crossentropy: 2.5654 - val_masked_loss: 2.7757 - val_sparse_categorical_accuracy: 0.4031
# Epoch 27/200
# 57/57 [==============================] - 6s 111ms/step - loss: 1.0187 - sparse_categorical_crossentropy: 2.0739 - masked_loss: 2.2440 - sparse_categorical_accuracy: 0.4733 - val_loss: 1.2385 - val_sparse_categorical_crossentropy: 2.5344 - val_masked_loss: 2.7422 - val_sparse_categorical_accuracy: 0.4081
# Epoch 28/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.9880 - sparse_categorical_crossentropy: 2.0099 - masked_loss: 2.1770 - sparse_categorical_accuracy: 0.4892 - val_loss: 1.2340 - val_sparse_categorical_crossentropy: 2.5252 - val_masked_loss: 2.7322 - val_sparse_categorical_accuracy: 0.4171
# Epoch 29/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.9443 - sparse_categorical_crossentropy: 1.9634 - masked_loss: 2.1269 - sparse_categorical_accuracy: 0.4970 - val_loss: 1.2454 - val_sparse_categorical_crossentropy: 2.5486 - val_masked_loss: 2.7575 - val_sparse_categorical_accuracy: 0.4149
# Epoch 30/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.9238 - sparse_categorical_crossentropy: 1.8887 - masked_loss: 2.0449 - sparse_categorical_accuracy: 0.5121 - val_loss: 1.2449 - val_sparse_categorical_crossentropy: 2.5475 - val_masked_loss: 2.7564 - val_sparse_categorical_accuracy: 0.4228
# Epoch 31/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.9038 - sparse_categorical_crossentropy: 1.8380 - masked_loss: 1.9879 - sparse_categorical_accuracy: 0.5250 - val_loss: 1.2749 - val_sparse_categorical_crossentropy: 2.6090 - val_masked_loss: 2.8229 - val_sparse_categorical_accuracy: 0.4210
# Epoch 32/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.8668 - sparse_categorical_crossentropy: 1.7711 - masked_loss: 1.9190 - sparse_categorical_accuracy: 0.5376 - val_loss: 1.2463 - val_sparse_categorical_crossentropy: 2.5504 - val_masked_loss: 2.7595 - val_sparse_categorical_accuracy: 0.4311
# Epoch 33/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.8378 - sparse_categorical_crossentropy: 1.7498 - masked_loss: 1.8941 - sparse_categorical_accuracy: 0.5424 - val_loss: 1.2596 - val_sparse_categorical_crossentropy: 2.5776 - val_masked_loss: 2.7889 - val_sparse_categorical_accuracy: 0.4302
# Epoch 34/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.8262 - sparse_categorical_crossentropy: 1.6724 - masked_loss: 1.8100 - sparse_categorical_accuracy: 0.5582 - val_loss: 1.2472 - val_sparse_categorical_crossentropy: 2.5522 - val_masked_loss: 2.7615 - val_sparse_categorical_accuracy: 0.4396
# Epoch 35/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.7912 - sparse_categorical_crossentropy: 1.6249 - masked_loss: 1.7597 - sparse_categorical_accuracy: 0.5696 - val_loss: 1.2550 - val_sparse_categorical_crossentropy: 2.5682 - val_masked_loss: 2.7788 - val_sparse_categorical_accuracy: 0.4400
# Epoch 36/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.7632 - sparse_categorical_crossentropy: 1.5666 - masked_loss: 1.6953 - sparse_categorical_accuracy: 0.5843 - val_loss: 1.2547 - val_sparse_categorical_crossentropy: 2.5676 - val_masked_loss: 2.7781 - val_sparse_categorical_accuracy: 0.4433
# Epoch 37/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.7495 - sparse_categorical_crossentropy: 1.5504 - masked_loss: 1.6791 - sparse_categorical_accuracy: 0.5882 - val_loss: 1.2858 - val_sparse_categorical_crossentropy: 2.6312 - val_masked_loss: 2.8469 - val_sparse_categorical_accuracy: 0.4433
# Epoch 38/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.7204 - sparse_categorical_crossentropy: 1.4723 - masked_loss: 1.5936 - sparse_categorical_accuracy: 0.6044 - val_loss: 1.2528 - val_sparse_categorical_crossentropy: 2.5638 - val_masked_loss: 2.7740 - val_sparse_categorical_accuracy: 0.4514
# Epoch 39/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.6932 - sparse_categorical_crossentropy: 1.4283 - masked_loss: 1.5470 - sparse_categorical_accuracy: 0.6144 - val_loss: 1.3104 - val_sparse_categorical_crossentropy: 2.6815 - val_masked_loss: 2.9014 - val_sparse_categorical_accuracy: 0.4398
# Epoch 40/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.6714 - sparse_categorical_crossentropy: 1.3828 - masked_loss: 1.4974 - sparse_categorical_accuracy: 0.6271 - val_loss: 1.2849 - val_sparse_categorical_crossentropy: 2.6293 - val_masked_loss: 2.8449 - val_sparse_categorical_accuracy: 0.4501
# Epoch 41/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.6581 - sparse_categorical_crossentropy: 1.3413 - masked_loss: 1.4515 - sparse_categorical_accuracy: 0.6314 - val_loss: 1.3056 - val_sparse_categorical_crossentropy: 2.6718 - val_masked_loss: 2.8909 - val_sparse_categorical_accuracy: 0.4547
# Epoch 42/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.6361 - sparse_categorical_crossentropy: 1.2950 - masked_loss: 1.4026 - sparse_categorical_accuracy: 0.6426 - val_loss: 1.3007 - val_sparse_categorical_crossentropy: 2.6617 - val_masked_loss: 2.8799 - val_sparse_categorical_accuracy: 0.4586
# Epoch 43/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.6119 - sparse_categorical_crossentropy: 1.2588 - masked_loss: 1.3625 - sparse_categorical_accuracy: 0.6498 - val_loss: 1.3383 - val_sparse_categorical_crossentropy: 2.7386 - val_masked_loss: 2.9632 - val_sparse_categorical_accuracy: 0.4479
# Epoch 44/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.6006 - sparse_categorical_crossentropy: 1.2325 - masked_loss: 1.3347 - sparse_categorical_accuracy: 0.6574 - val_loss: 1.3452 - val_sparse_categorical_crossentropy: 2.7527 - val_masked_loss: 2.9785 - val_sparse_categorical_accuracy: 0.4514
# Epoch 45/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.5702 - sparse_categorical_crossentropy: 1.1737 - masked_loss: 1.2706 - sparse_categorical_accuracy: 0.6725 - val_loss: 1.3485 - val_sparse_categorical_crossentropy: 2.7597 - val_masked_loss: 2.9859 - val_sparse_categorical_accuracy: 0.4553
# Epoch 46/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.5637 - sparse_categorical_crossentropy: 1.1490 - masked_loss: 1.2439 - sparse_categorical_accuracy: 0.6774 - val_loss: 1.3769 - val_sparse_categorical_crossentropy: 2.8177 - val_masked_loss: 3.0488 - val_sparse_categorical_accuracy: 0.4557
# Epoch 47/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.5435 - sparse_categorical_crossentropy: 1.0979 - masked_loss: 1.1885 - sparse_categorical_accuracy: 0.6898 - val_loss: 1.3807 - val_sparse_categorical_crossentropy: 2.8254 - val_masked_loss: 3.0570 - val_sparse_categorical_accuracy: 0.4635
# Epoch 48/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.5292 - sparse_categorical_crossentropy: 1.0874 - masked_loss: 1.1775 - sparse_categorical_accuracy: 0.6913 - val_loss: 1.3649 - val_sparse_categorical_crossentropy: 2.7931 - val_masked_loss: 3.0221 - val_sparse_categorical_accuracy: 0.4601
# Epoch 49/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.5127 - sparse_categorical_crossentropy: 1.0509 - masked_loss: 1.1373 - sparse_categorical_accuracy: 0.6996 - val_loss: 1.3751 - val_sparse_categorical_crossentropy: 2.8140 - val_masked_loss: 3.0448 - val_sparse_categorical_accuracy: 0.4635
# Epoch 50/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.4965 - sparse_categorical_crossentropy: 1.0052 - masked_loss: 1.0884 - sparse_categorical_accuracy: 0.7123 - val_loss: 1.4066 - val_sparse_categorical_crossentropy: 2.8784 - val_masked_loss: 3.1144 - val_sparse_categorical_accuracy: 0.4585
# Epoch 51/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.4718 - sparse_categorical_crossentropy: 0.9692 - masked_loss: 1.0490 - sparse_categorical_accuracy: 0.7188 - val_loss: 1.4033 - val_sparse_categorical_crossentropy: 2.8716 - val_masked_loss: 3.1072 - val_sparse_categorical_accuracy: 0.4643
# Epoch 52/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.4692 - sparse_categorical_crossentropy: 0.9569 - masked_loss: 1.0360 - sparse_categorical_accuracy: 0.7209 - val_loss: 1.4406 - val_sparse_categorical_crossentropy: 2.9481 - val_masked_loss: 3.1899 - val_sparse_categorical_accuracy: 0.4642
# Epoch 53/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.4427 - sparse_categorical_crossentropy: 0.9051 - masked_loss: 0.9801 - sparse_categorical_accuracy: 0.7346 - val_loss: 1.4357 - val_sparse_categorical_crossentropy: 2.9381 - val_masked_loss: 3.1791 - val_sparse_categorical_accuracy: 0.4604
# Epoch 54/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.4396 - sparse_categorical_crossentropy: 0.8956 - masked_loss: 0.9696 - sparse_categorical_accuracy: 0.7367 - val_loss: 1.4595 - val_sparse_categorical_crossentropy: 2.9867 - val_masked_loss: 3.2317 - val_sparse_categorical_accuracy: 0.4613
# Epoch 55/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.4226 - sparse_categorical_crossentropy: 0.8726 - masked_loss: 0.9448 - sparse_categorical_accuracy: 0.7421 - val_loss: 1.4726 - val_sparse_categorical_crossentropy: 3.0134 - val_masked_loss: 3.2605 - val_sparse_categorical_accuracy: 0.4672
# Epoch 56/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.4157 - sparse_categorical_crossentropy: 0.8461 - masked_loss: 0.9158 - sparse_categorical_accuracy: 0.7475 - val_loss: 1.4884 - val_sparse_categorical_crossentropy: 3.0457 - val_masked_loss: 3.2955 - val_sparse_categorical_accuracy: 0.4607
# Epoch 57/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.4043 - sparse_categorical_crossentropy: 0.8311 - masked_loss: 0.8997 - sparse_categorical_accuracy: 0.7523 - val_loss: 1.5359 - val_sparse_categorical_crossentropy: 3.1430 - val_masked_loss: 3.4006 - val_sparse_categorical_accuracy: 0.4577
# Epoch 58/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3930 - sparse_categorical_crossentropy: 0.8021 - masked_loss: 0.8684 - sparse_categorical_accuracy: 0.7606 - val_loss: 1.5208 - val_sparse_categorical_crossentropy: 3.1122 - val_masked_loss: 3.3674 - val_sparse_categorical_accuracy: 0.4592
# Epoch 59/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3748 - sparse_categorical_crossentropy: 0.7704 - masked_loss: 0.8340 - sparse_categorical_accuracy: 0.7666 - val_loss: 1.5320 - val_sparse_categorical_crossentropy: 3.1350 - val_masked_loss: 3.3921 - val_sparse_categorical_accuracy: 0.4665
# Epoch 60/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.3724 - sparse_categorical_crossentropy: 0.7643 - masked_loss: 0.8274 - sparse_categorical_accuracy: 0.7685 - val_loss: 1.5316 - val_sparse_categorical_crossentropy: 3.1343 - val_masked_loss: 3.3913 - val_sparse_categorical_accuracy: 0.4683
# Epoch 61/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.3583 - sparse_categorical_crossentropy: 0.7338 - masked_loss: 0.7945 - sparse_categorical_accuracy: 0.7789 - val_loss: 1.5418 - val_sparse_categorical_crossentropy: 3.1551 - val_masked_loss: 3.4137 - val_sparse_categorical_accuracy: 0.4644
# Epoch 62/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3465 - sparse_categorical_crossentropy: 0.7175 - masked_loss: 0.7769 - sparse_categorical_accuracy: 0.7814 - val_loss: 1.5690 - val_sparse_categorical_crossentropy: 3.2108 - val_masked_loss: 3.4740 - val_sparse_categorical_accuracy: 0.4670
# Epoch 63/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3372 - sparse_categorical_crossentropy: 0.7000 - masked_loss: 0.7579 - sparse_categorical_accuracy: 0.7838 - val_loss: 1.6084 - val_sparse_categorical_crossentropy: 3.2913 - val_masked_loss: 3.5612 - val_sparse_categorical_accuracy: 0.4607
# Epoch 64/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3297 - sparse_categorical_crossentropy: 0.6743 - masked_loss: 0.7297 - sparse_categorical_accuracy: 0.7916 - val_loss: 1.5959 - val_sparse_categorical_crossentropy: 3.2658 - val_masked_loss: 3.5336 - val_sparse_categorical_accuracy: 0.4661
# Epoch 65/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.3323 - sparse_categorical_crossentropy: 0.6798 - masked_loss: 0.7359 - sparse_categorical_accuracy: 0.7918 - val_loss: 1.6012 - val_sparse_categorical_crossentropy: 3.2766 - val_masked_loss: 3.5453 - val_sparse_categorical_accuracy: 0.4709
# Epoch 66/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.3190 - sparse_categorical_crossentropy: 0.6544 - masked_loss: 0.7086 - sparse_categorical_accuracy: 0.7979 - val_loss: 1.6405 - val_sparse_categorical_crossentropy: 3.3571 - val_masked_loss: 3.6323 - val_sparse_categorical_accuracy: 0.4720
# Epoch 67/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3072 - sparse_categorical_crossentropy: 0.6362 - masked_loss: 0.6888 - sparse_categorical_accuracy: 0.8011 - val_loss: 1.6688 - val_sparse_categorical_crossentropy: 3.4151 - val_masked_loss: 3.6950 - val_sparse_categorical_accuracy: 0.4667
# Epoch 68/200
# 57/57 [==============================] - 7s 116ms/step - loss: 0.3017 - sparse_categorical_crossentropy: 0.6214 - masked_loss: 0.6729 - sparse_categorical_accuracy: 0.8085 - val_loss: 1.6647 - val_sparse_categorical_crossentropy: 3.4066 - val_masked_loss: 3.6859 - val_sparse_categorical_accuracy: 0.4683
# Epoch 69/200
# 57/57 [==============================] - 7s 118ms/step - loss: 0.3047 - sparse_categorical_crossentropy: 0.6305 - masked_loss: 0.6828 - sparse_categorical_accuracy: 0.8045 - val_loss: 1.6648 - val_sparse_categorical_crossentropy: 3.4069 - val_masked_loss: 3.6862 - val_sparse_categorical_accuracy: 0.4642
# Epoch 70/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2935 - sparse_categorical_crossentropy: 0.6045 - masked_loss: 0.6546 - sparse_categorical_accuracy: 0.8113 - val_loss: 1.6912 - val_sparse_categorical_crossentropy: 3.4609 - val_masked_loss: 3.7447 - val_sparse_categorical_accuracy: 0.4710
# Epoch 71/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.2857 - sparse_categorical_crossentropy: 0.5816 - masked_loss: 0.6294 - sparse_categorical_accuracy: 0.8164 - val_loss: 1.6799 - val_sparse_categorical_crossentropy: 3.4378 - val_masked_loss: 3.7197 - val_sparse_categorical_accuracy: 0.4729
# Epoch 72/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.2817 - sparse_categorical_crossentropy: 0.5786 - masked_loss: 0.6263 - sparse_categorical_accuracy: 0.8195 - val_loss: 1.6847 - val_sparse_categorical_crossentropy: 3.4475 - val_masked_loss: 3.7301 - val_sparse_categorical_accuracy: 0.4728
# Epoch 73/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2686 - sparse_categorical_crossentropy: 0.5521 - masked_loss: 0.5977 - sparse_categorical_accuracy: 0.8272 - val_loss: 1.7448 - val_sparse_categorical_crossentropy: 3.5705 - val_masked_loss: 3.8632 - val_sparse_categorical_accuracy: 0.4671
# Epoch 74/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2577 - sparse_categorical_crossentropy: 0.5305 - masked_loss: 0.5743 - sparse_categorical_accuracy: 0.8326 - val_loss: 1.7447 - val_sparse_categorical_crossentropy: 3.5704 - val_masked_loss: 3.8631 - val_sparse_categorical_accuracy: 0.4642
# Epoch 75/200
# 57/57 [==============================] - 10s 180ms/step - loss: 0.2534 - sparse_categorical_crossentropy: 0.5280 - masked_loss: 0.5718 - sparse_categorical_accuracy: 0.8333 - val_loss: 1.7133 - val_sparse_categorical_crossentropy: 3.5060 - val_masked_loss: 3.7934 - val_sparse_categorical_accuracy: 0.4774
# Epoch 76/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2434 - sparse_categorical_crossentropy: 0.4978 - masked_loss: 0.5388 - sparse_categorical_accuracy: 0.8425 - val_loss: 1.7886 - val_sparse_categorical_crossentropy: 3.6602 - val_masked_loss: 3.9603 - val_sparse_categorical_accuracy: 0.4716
# Epoch 77/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2327 - sparse_categorical_crossentropy: 0.4763 - masked_loss: 0.5155 - sparse_categorical_accuracy: 0.8482 - val_loss: 1.7434 - val_sparse_categorical_crossentropy: 3.5677 - val_masked_loss: 3.8603 - val_sparse_categorical_accuracy: 0.4725
# Epoch 78/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2256 - sparse_categorical_crossentropy: 0.4681 - masked_loss: 0.5065 - sparse_categorical_accuracy: 0.8504 - val_loss: 1.7783 - val_sparse_categorical_crossentropy: 3.6392 - val_masked_loss: 3.9376 - val_sparse_categorical_accuracy: 0.4765
# Epoch 79/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2172 - sparse_categorical_crossentropy: 0.4458 - masked_loss: 0.4831 - sparse_categorical_accuracy: 0.8584 - val_loss: 1.7756 - val_sparse_categorical_crossentropy: 3.6336 - val_masked_loss: 3.9315 - val_sparse_categorical_accuracy: 0.4791
# Epoch 80/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.2151 - sparse_categorical_crossentropy: 0.4300 - masked_loss: 0.4653 - sparse_categorical_accuracy: 0.8640 - val_loss: 1.8258 - val_sparse_categorical_crossentropy: 3.7363 - val_masked_loss: 4.0426 - val_sparse_categorical_accuracy: 0.4731
# Epoch 81/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.2089 - sparse_categorical_crossentropy: 0.4277 - masked_loss: 0.4628 - sparse_categorical_accuracy: 0.8650 - val_loss: 1.8554 - val_sparse_categorical_crossentropy: 3.7970 - val_masked_loss: 4.1082 - val_sparse_categorical_accuracy: 0.4763
# Epoch 82/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2002 - sparse_categorical_crossentropy: 0.4153 - masked_loss: 0.4496 - sparse_categorical_accuracy: 0.8669 - val_loss: 1.8443 - val_sparse_categorical_crossentropy: 3.7741 - val_masked_loss: 4.0836 - val_sparse_categorical_accuracy: 0.4782
# Epoch 83/200
# 57/57 [==============================] - 6s 114ms/step - loss: 0.1923 - sparse_categorical_crossentropy: 0.3945 - masked_loss: 0.4270 - sparse_categorical_accuracy: 0.8735 - val_loss: 1.8589 - val_sparse_categorical_crossentropy: 3.8040 - val_masked_loss: 4.1159 - val_sparse_categorical_accuracy: 0.4769
# Epoch 84/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1883 - sparse_categorical_crossentropy: 0.3837 - masked_loss: 0.4154 - sparse_categorical_accuracy: 0.8786 - val_loss: 1.8852 - val_sparse_categorical_crossentropy: 3.8579 - val_masked_loss: 4.1743 - val_sparse_categorical_accuracy: 0.4783
# Epoch 85/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1795 - sparse_categorical_crossentropy: 0.3695 - masked_loss: 0.4003 - sparse_categorical_accuracy: 0.8824 - val_loss: 1.9126 - val_sparse_categorical_crossentropy: 3.9139 - val_masked_loss: 4.2348 - val_sparse_categorical_accuracy: 0.4746
# Epoch 86/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1767 - sparse_categorical_crossentropy: 0.3638 - masked_loss: 0.3937 - sparse_categorical_accuracy: 0.8833 - val_loss: 1.8903 - val_sparse_categorical_crossentropy: 3.8682 - val_masked_loss: 4.1853 - val_sparse_categorical_accuracy: 0.4795
# Epoch 87/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.1766 - sparse_categorical_crossentropy: 0.3586 - masked_loss: 0.3882 - sparse_categorical_accuracy: 0.8848 - val_loss: 1.9159 - val_sparse_categorical_crossentropy: 3.9206 - val_masked_loss: 4.2421 - val_sparse_categorical_accuracy: 0.4764
# Epoch 88/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1666 - sparse_categorical_crossentropy: 0.3459 - masked_loss: 0.3744 - sparse_categorical_accuracy: 0.8879 - val_loss: 1.9361 - val_sparse_categorical_crossentropy: 3.9620 - val_masked_loss: 4.2868 - val_sparse_categorical_accuracy: 0.4758
# Epoch 89/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1612 - sparse_categorical_crossentropy: 0.3309 - masked_loss: 0.3582 - sparse_categorical_accuracy: 0.8938 - val_loss: 1.9866 - val_sparse_categorical_crossentropy: 4.0654 - val_masked_loss: 4.3986 - val_sparse_categorical_accuracy: 0.4714
# Epoch 90/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1593 - sparse_categorical_crossentropy: 0.3269 - masked_loss: 0.3541 - sparse_categorical_accuracy: 0.8940 - val_loss: 1.9629 - val_sparse_categorical_crossentropy: 4.0169 - val_masked_loss: 4.3463 - val_sparse_categorical_accuracy: 0.4772
# Epoch 91/200
# 57/57 [==============================] - 6s 115ms/step - loss: 0.1559 - sparse_categorical_crossentropy: 0.3176 - masked_loss: 0.3438 - sparse_categorical_accuracy: 0.8968 - val_loss: 1.9783 - val_sparse_categorical_crossentropy: 4.0484 - val_masked_loss: 4.3804 - val_sparse_categorical_accuracy: 0.4803
# Epoch 92/200
# 57/57 [==============================] - 6s 114ms/step - loss: 0.1520 - sparse_categorical_crossentropy: 0.3135 - masked_loss: 0.3393 - sparse_categorical_accuracy: 0.8984 - val_loss: 1.9815 - val_sparse_categorical_crossentropy: 4.0548 - val_masked_loss: 4.3873 - val_sparse_categorical_accuracy: 0.4833
# Epoch 93/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.1419 - sparse_categorical_crossentropy: 0.2939 - masked_loss: 0.3182 - sparse_categorical_accuracy: 0.9052 - val_loss: 2.0108 - val_sparse_categorical_crossentropy: 4.1148 - val_masked_loss: 4.4521 - val_sparse_categorical_accuracy: 0.4756
# Epoch 94/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1465 - sparse_categorical_crossentropy: 0.3005 - masked_loss: 0.3254 - sparse_categorical_accuracy: 0.9035 - val_loss: 1.9656 - val_sparse_categorical_crossentropy: 4.0225 - val_masked_loss: 4.3523 - val_sparse_categorical_accuracy: 0.4805
# Epoch 95/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1362 - sparse_categorical_crossentropy: 0.2818 - masked_loss: 0.3051 - sparse_categorical_accuracy: 0.9090 - val_loss: 2.0217 - val_sparse_categorical_crossentropy: 4.1371 - val_masked_loss: 4.4762 - val_sparse_categorical_accuracy: 0.4780
# Epoch 96/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1392 - sparse_categorical_crossentropy: 0.2846 - masked_loss: 0.3080 - sparse_categorical_accuracy: 0.9080 - val_loss: 2.0376 - val_sparse_categorical_crossentropy: 4.1697 - val_masked_loss: 4.5116 - val_sparse_categorical_accuracy: 0.4802
# Epoch 97/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1366 - sparse_categorical_crossentropy: 0.2799 - masked_loss: 0.3030 - sparse_categorical_accuracy: 0.9101 - val_loss: 2.0698 - val_sparse_categorical_crossentropy: 4.2357 - val_masked_loss: 4.5830 - val_sparse_categorical_accuracy: 0.4772
# Epoch 98/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1302 - sparse_categorical_crossentropy: 0.2692 - masked_loss: 0.2914 - sparse_categorical_accuracy: 0.9121 - val_loss: 2.0797 - val_sparse_categorical_crossentropy: 4.2560 - val_masked_loss: 4.6050 - val_sparse_categorical_accuracy: 0.4778
# Epoch 99/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1279 - sparse_categorical_crossentropy: 0.2656 - masked_loss: 0.2875 - sparse_categorical_accuracy: 0.9152 - val_loss: 2.0637 - val_sparse_categorical_crossentropy: 4.2232 - val_masked_loss: 4.5694 - val_sparse_categorical_accuracy: 0.4789
# Epoch 100/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1226 - sparse_categorical_crossentropy: 0.2527 - masked_loss: 0.2737 - sparse_categorical_accuracy: 0.9168 - val_loss: 2.0852 - val_sparse_categorical_crossentropy: 4.2671 - val_masked_loss: 4.6169 - val_sparse_categorical_accuracy: 0.4803
# Epoch 101/200
# 57/57 [==============================] - 10s 181ms/step - loss: 0.1240 - sparse_categorical_crossentropy: 0.2525 - masked_loss: 0.2733 - sparse_categorical_accuracy: 0.9184 - val_loss: 2.0739 - val_sparse_categorical_crossentropy: 4.2439 - val_masked_loss: 4.5918 - val_sparse_categorical_accuracy: 0.4830
# Epoch 102/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1225 - sparse_categorical_crossentropy: 0.2517 - masked_loss: 0.2725 - sparse_categorical_accuracy: 0.9193 - val_loss: 2.0725 - val_sparse_categorical_crossentropy: 4.2410 - val_masked_loss: 4.5888 - val_sparse_categorical_accuracy: 0.4822
# Epoch 103/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1181 - sparse_categorical_crossentropy: 0.2436 - masked_loss: 0.2639 - sparse_categorical_accuracy: 0.9217 - val_loss: 2.1154 - val_sparse_categorical_crossentropy: 4.3290 - val_masked_loss: 4.6838 - val_sparse_categorical_accuracy: 0.4720
# Epoch 104/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1118 - sparse_categorical_crossentropy: 0.2289 - masked_loss: 0.2477 - sparse_categorical_accuracy: 0.9267 - val_loss: 2.1401 - val_sparse_categorical_crossentropy: 4.3794 - val_masked_loss: 4.7386 - val_sparse_categorical_accuracy: 0.4782
# Epoch 105/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1202 - sparse_categorical_crossentropy: 0.2449 - masked_loss: 0.2651 - sparse_categorical_accuracy: 0.9209 - val_loss: 2.1155 - val_sparse_categorical_crossentropy: 4.3291 - val_masked_loss: 4.6841 - val_sparse_categorical_accuracy: 0.4826
# Epoch 106/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1081 - sparse_categorical_crossentropy: 0.2249 - masked_loss: 0.2434 - sparse_categorical_accuracy: 0.9274 - val_loss: 2.1225 - val_sparse_categorical_crossentropy: 4.3435 - val_masked_loss: 4.6996 - val_sparse_categorical_accuracy: 0.4814
# Epoch 107/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1126 - sparse_categorical_crossentropy: 0.2315 - masked_loss: 0.2506 - sparse_categorical_accuracy: 0.9251 - val_loss: 2.1135 - val_sparse_categorical_crossentropy: 4.3251 - val_masked_loss: 4.6797 - val_sparse_categorical_accuracy: 0.4822
# Epoch 108/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.1093 - sparse_categorical_crossentropy: 0.2251 - masked_loss: 0.2436 - sparse_categorical_accuracy: 0.9287 - val_loss: 2.1237 - val_sparse_categorical_crossentropy: 4.3460 - val_masked_loss: 4.7022 - val_sparse_categorical_accuracy: 0.4868
# Epoch 109/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1016 - sparse_categorical_crossentropy: 0.2101 - masked_loss: 0.2276 - sparse_categorical_accuracy: 0.9315 - val_loss: 2.1428 - val_sparse_categorical_crossentropy: 4.3851 - val_masked_loss: 4.7446 - val_sparse_categorical_accuracy: 0.4817
# Epoch 110/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1007 - sparse_categorical_crossentropy: 0.2055 - masked_loss: 0.2225 - sparse_categorical_accuracy: 0.9343 - val_loss: 2.1270 - val_sparse_categorical_crossentropy: 4.3527 - val_masked_loss: 4.7096 - val_sparse_categorical_accuracy: 0.4806
# Epoch 111/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.1001 - sparse_categorical_crossentropy: 0.2073 - masked_loss: 0.2244 - sparse_categorical_accuracy: 0.9343 - val_loss: 2.1605 - val_sparse_categorical_crossentropy: 4.4212 - val_masked_loss: 4.7837 - val_sparse_categorical_accuracy: 0.4879
# Epoch 112/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.1027 - sparse_categorical_crossentropy: 0.2102 - masked_loss: 0.2276 - sparse_categorical_accuracy: 0.9322 - val_loss: 2.1959 - val_sparse_categorical_crossentropy: 4.4937 - val_masked_loss: 4.8622 - val_sparse_categorical_accuracy: 0.4776
# Epoch 113/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0963 - sparse_categorical_crossentropy: 0.1968 - masked_loss: 0.2130 - sparse_categorical_accuracy: 0.9360 - val_loss: 2.1811 - val_sparse_categorical_crossentropy: 4.4634 - val_masked_loss: 4.8296 - val_sparse_categorical_accuracy: 0.4787
# Epoch 114/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0959 - sparse_categorical_crossentropy: 0.1951 - masked_loss: 0.2112 - sparse_categorical_accuracy: 0.9363 - val_loss: 2.2115 - val_sparse_categorical_crossentropy: 4.5257 - val_masked_loss: 4.8968 - val_sparse_categorical_accuracy: 0.4787
# Epoch 115/200
# 57/57 [==============================] - 6s 114ms/step - loss: 0.0968 - sparse_categorical_crossentropy: 0.1989 - masked_loss: 0.2154 - sparse_categorical_accuracy: 0.9356 - val_loss: 2.2015 - val_sparse_categorical_crossentropy: 4.5052 - val_masked_loss: 4.8747 - val_sparse_categorical_accuracy: 0.4795
# Epoch 116/200
# 57/57 [==============================] - 7s 117ms/step - loss: 0.0951 - sparse_categorical_crossentropy: 0.1960 - masked_loss: 0.2122 - sparse_categorical_accuracy: 0.9362 - val_loss: 2.2400 - val_sparse_categorical_crossentropy: 4.5839 - val_masked_loss: 4.9598 - val_sparse_categorical_accuracy: 0.4834
# Epoch 117/200
# 57/57 [==============================] - 7s 116ms/step - loss: 0.0921 - sparse_categorical_crossentropy: 0.1872 - masked_loss: 0.2027 - sparse_categorical_accuracy: 0.9394 - val_loss: 2.2475 - val_sparse_categorical_crossentropy: 4.5993 - val_masked_loss: 4.9764 - val_sparse_categorical_accuracy: 0.4728
# Epoch 118/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0912 - sparse_categorical_crossentropy: 0.1867 - masked_loss: 0.2021 - sparse_categorical_accuracy: 0.9405 - val_loss: 2.2541 - val_sparse_categorical_crossentropy: 4.6127 - val_masked_loss: 4.9909 - val_sparse_categorical_accuracy: 0.4772
# Epoch 119/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0902 - sparse_categorical_crossentropy: 0.1859 - masked_loss: 0.2013 - sparse_categorical_accuracy: 0.9378 - val_loss: 2.2578 - val_sparse_categorical_crossentropy: 4.6203 - val_masked_loss: 4.9991 - val_sparse_categorical_accuracy: 0.4721
# Epoch 120/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0905 - sparse_categorical_crossentropy: 0.1845 - masked_loss: 0.1997 - sparse_categorical_accuracy: 0.9403 - val_loss: 2.2311 - val_sparse_categorical_crossentropy: 4.5656 - val_masked_loss: 4.9401 - val_sparse_categorical_accuracy: 0.4822
# Epoch 121/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0847 - sparse_categorical_crossentropy: 0.1742 - masked_loss: 0.1886 - sparse_categorical_accuracy: 0.9434 - val_loss: 2.2895 - val_sparse_categorical_crossentropy: 4.6851 - val_masked_loss: 5.0692 - val_sparse_categorical_accuracy: 0.4729
# Epoch 122/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0837 - sparse_categorical_crossentropy: 0.1724 - masked_loss: 0.1867 - sparse_categorical_accuracy: 0.9440 - val_loss: 2.3036 - val_sparse_categorical_crossentropy: 4.7140 - val_masked_loss: 5.1004 - val_sparse_categorical_accuracy: 0.4777
# Epoch 123/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0818 - sparse_categorical_crossentropy: 0.1679 - masked_loss: 0.1818 - sparse_categorical_accuracy: 0.9452 - val_loss: 2.2943 - val_sparse_categorical_crossentropy: 4.6951 - val_masked_loss: 5.0798 - val_sparse_categorical_accuracy: 0.4743
# Epoch 124/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0816 - sparse_categorical_crossentropy: 0.1686 - masked_loss: 0.1825 - sparse_categorical_accuracy: 0.9444 - val_loss: 2.2613 - val_sparse_categorical_crossentropy: 4.6275 - val_masked_loss: 5.0069 - val_sparse_categorical_accuracy: 0.4787
# Epoch 125/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0797 - sparse_categorical_crossentropy: 0.1628 - masked_loss: 0.1762 - sparse_categorical_accuracy: 0.9474 - val_loss: 2.3161 - val_sparse_categorical_crossentropy: 4.7396 - val_masked_loss: 5.1281 - val_sparse_categorical_accuracy: 0.4819
# Epoch 126/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0782 - sparse_categorical_crossentropy: 0.1635 - masked_loss: 0.1770 - sparse_categorical_accuracy: 0.9474 - val_loss: 2.2909 - val_sparse_categorical_crossentropy: 4.6882 - val_masked_loss: 5.0725 - val_sparse_categorical_accuracy: 0.4792
# Epoch 127/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0769 - sparse_categorical_crossentropy: 0.1580 - masked_loss: 0.1709 - sparse_categorical_accuracy: 0.9483 - val_loss: 2.3019 - val_sparse_categorical_crossentropy: 4.7106 - val_masked_loss: 5.0968 - val_sparse_categorical_accuracy: 0.4816
# Epoch 128/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0790 - sparse_categorical_crossentropy: 0.1626 - masked_loss: 0.1759 - sparse_categorical_accuracy: 0.9478 - val_loss: 2.2995 - val_sparse_categorical_crossentropy: 4.7056 - val_masked_loss: 5.0914 - val_sparse_categorical_accuracy: 0.4769
# Epoch 129/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0742 - sparse_categorical_crossentropy: 0.1534 - masked_loss: 0.1660 - sparse_categorical_accuracy: 0.9497 - val_loss: 2.3243 - val_sparse_categorical_crossentropy: 4.7564 - val_masked_loss: 5.1464 - val_sparse_categorical_accuracy: 0.4820
# Epoch 130/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0761 - sparse_categorical_crossentropy: 0.1559 - masked_loss: 0.1688 - sparse_categorical_accuracy: 0.9491 - val_loss: 2.3429 - val_sparse_categorical_crossentropy: 4.7945 - val_masked_loss: 5.1875 - val_sparse_categorical_accuracy: 0.4843
# Epoch 131/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0778 - sparse_categorical_crossentropy: 0.1563 - masked_loss: 0.1692 - sparse_categorical_accuracy: 0.9494 - val_loss: 2.3219 - val_sparse_categorical_crossentropy: 4.7515 - val_masked_loss: 5.1410 - val_sparse_categorical_accuracy: 0.4799
# Epoch 132/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0728 - sparse_categorical_crossentropy: 0.1510 - masked_loss: 0.1635 - sparse_categorical_accuracy: 0.9516 - val_loss: 2.3318 - val_sparse_categorical_crossentropy: 4.7717 - val_masked_loss: 5.1628 - val_sparse_categorical_accuracy: 0.4801
# Epoch 133/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0720 - sparse_categorical_crossentropy: 0.1484 - masked_loss: 0.1607 - sparse_categorical_accuracy: 0.9515 - val_loss: 2.3472 - val_sparse_categorical_crossentropy: 4.8032 - val_masked_loss: 5.1971 - val_sparse_categorical_accuracy: 0.4757
# Epoch 134/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0708 - sparse_categorical_crossentropy: 0.1435 - masked_loss: 0.1553 - sparse_categorical_accuracy: 0.9537 - val_loss: 2.3680 - val_sparse_categorical_crossentropy: 4.8459 - val_masked_loss: 5.2434 - val_sparse_categorical_accuracy: 0.4778
# Epoch 135/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0716 - sparse_categorical_crossentropy: 0.1486 - masked_loss: 0.1608 - sparse_categorical_accuracy: 0.9530 - val_loss: 2.3924 - val_sparse_categorical_crossentropy: 4.8957 - val_masked_loss: 5.2972 - val_sparse_categorical_accuracy: 0.4798
# Epoch 136/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0737 - sparse_categorical_crossentropy: 0.1513 - masked_loss: 0.1639 - sparse_categorical_accuracy: 0.9512 - val_loss: 2.3356 - val_sparse_categorical_crossentropy: 4.7795 - val_masked_loss: 5.1714 - val_sparse_categorical_accuracy: 0.4798
# Epoch 137/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0661 - sparse_categorical_crossentropy: 0.1348 - masked_loss: 0.1459 - sparse_categorical_accuracy: 0.9559 - val_loss: 2.4033 - val_sparse_categorical_crossentropy: 4.9181 - val_masked_loss: 5.3215 - val_sparse_categorical_accuracy: 0.4795
# Epoch 138/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0688 - sparse_categorical_crossentropy: 0.1404 - masked_loss: 0.1520 - sparse_categorical_accuracy: 0.9549 - val_loss: 2.3951 - val_sparse_categorical_crossentropy: 4.9013 - val_masked_loss: 5.3031 - val_sparse_categorical_accuracy: 0.4774
# Epoch 139/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0669 - sparse_categorical_crossentropy: 0.1390 - masked_loss: 0.1505 - sparse_categorical_accuracy: 0.9557 - val_loss: 2.3617 - val_sparse_categorical_crossentropy: 4.8330 - val_masked_loss: 5.2293 - val_sparse_categorical_accuracy: 0.4839
# Epoch 140/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0667 - sparse_categorical_crossentropy: 0.1362 - masked_loss: 0.1473 - sparse_categorical_accuracy: 0.9559 - val_loss: 2.3876 - val_sparse_categorical_crossentropy: 4.8859 - val_masked_loss: 5.2866 - val_sparse_categorical_accuracy: 0.4843
# Epoch 141/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0638 - sparse_categorical_crossentropy: 0.1300 - masked_loss: 0.1408 - sparse_categorical_accuracy: 0.9582 - val_loss: 2.4566 - val_sparse_categorical_crossentropy: 5.0271 - val_masked_loss: 5.4391 - val_sparse_categorical_accuracy: 0.4712
# Epoch 142/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0666 - sparse_categorical_crossentropy: 0.1392 - masked_loss: 0.1507 - sparse_categorical_accuracy: 0.9552 - val_loss: 2.4375 - val_sparse_categorical_crossentropy: 4.9882 - val_masked_loss: 5.3972 - val_sparse_categorical_accuracy: 0.4802
# Epoch 143/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0643 - sparse_categorical_crossentropy: 0.1320 - masked_loss: 0.1429 - sparse_categorical_accuracy: 0.9564 - val_loss: 2.4608 - val_sparse_categorical_crossentropy: 5.0357 - val_masked_loss: 5.4487 - val_sparse_categorical_accuracy: 0.4748
# Epoch 144/200
# 57/57 [==============================] - 6s 114ms/step - loss: 0.0636 - sparse_categorical_crossentropy: 0.1297 - masked_loss: 0.1403 - sparse_categorical_accuracy: 0.9577 - val_loss: 2.4552 - val_sparse_categorical_crossentropy: 5.0244 - val_masked_loss: 5.4363 - val_sparse_categorical_accuracy: 0.4739
# Epoch 145/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0616 - sparse_categorical_crossentropy: 0.1265 - masked_loss: 0.1370 - sparse_categorical_accuracy: 0.9585 - val_loss: 2.4213 - val_sparse_categorical_crossentropy: 4.9549 - val_masked_loss: 5.3613 - val_sparse_categorical_accuracy: 0.4785
# Epoch 146/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0636 - sparse_categorical_crossentropy: 0.1283 - masked_loss: 0.1388 - sparse_categorical_accuracy: 0.9583 - val_loss: 2.4426 - val_sparse_categorical_crossentropy: 4.9985 - val_masked_loss: 5.4082 - val_sparse_categorical_accuracy: 0.4855
# Epoch 147/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0589 - sparse_categorical_crossentropy: 0.1230 - masked_loss: 0.1332 - sparse_categorical_accuracy: 0.9600 - val_loss: 2.4162 - val_sparse_categorical_crossentropy: 4.9444 - val_masked_loss: 5.3498 - val_sparse_categorical_accuracy: 0.4892
# Epoch 148/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0610 - sparse_categorical_crossentropy: 0.1256 - masked_loss: 0.1360 - sparse_categorical_accuracy: 0.9601 - val_loss: 2.4655 - val_sparse_categorical_crossentropy: 5.0453 - val_masked_loss: 5.4588 - val_sparse_categorical_accuracy: 0.4771
# Epoch 149/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0576 - sparse_categorical_crossentropy: 0.1177 - masked_loss: 0.1274 - sparse_categorical_accuracy: 0.9616 - val_loss: 2.4448 - val_sparse_categorical_crossentropy: 5.0030 - val_masked_loss: 5.4132 - val_sparse_categorical_accuracy: 0.4798
# Epoch 150/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0547 - sparse_categorical_crossentropy: 0.1116 - masked_loss: 0.1208 - sparse_categorical_accuracy: 0.9634 - val_loss: 2.4443 - val_sparse_categorical_crossentropy: 5.0021 - val_masked_loss: 5.4121 - val_sparse_categorical_accuracy: 0.4847
# Epoch 151/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0588 - sparse_categorical_crossentropy: 0.1213 - masked_loss: 0.1313 - sparse_categorical_accuracy: 0.9616 - val_loss: 2.4984 - val_sparse_categorical_crossentropy: 5.1126 - val_masked_loss: 5.5318 - val_sparse_categorical_accuracy: 0.4777
# Epoch 152/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0585 - sparse_categorical_crossentropy: 0.1202 - masked_loss: 0.1301 - sparse_categorical_accuracy: 0.9612 - val_loss: 2.4743 - val_sparse_categorical_crossentropy: 5.0634 - val_masked_loss: 5.4786 - val_sparse_categorical_accuracy: 0.4862
# Epoch 153/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0569 - sparse_categorical_crossentropy: 0.1171 - masked_loss: 0.1268 - sparse_categorical_accuracy: 0.9626 - val_loss: 2.4291 - val_sparse_categorical_crossentropy: 4.9708 - val_masked_loss: 5.3784 - val_sparse_categorical_accuracy: 0.4825
# Epoch 154/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0580 - sparse_categorical_crossentropy: 0.1194 - masked_loss: 0.1292 - sparse_categorical_accuracy: 0.9612 - val_loss: 2.4194 - val_sparse_categorical_crossentropy: 4.9511 - val_masked_loss: 5.3570 - val_sparse_categorical_accuracy: 0.4823
# Epoch 155/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0566 - sparse_categorical_crossentropy: 0.1163 - masked_loss: 0.1259 - sparse_categorical_accuracy: 0.9623 - val_loss: 2.4957 - val_sparse_categorical_crossentropy: 5.1071 - val_masked_loss: 5.5260 - val_sparse_categorical_accuracy: 0.4787
# Epoch 156/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0532 - sparse_categorical_crossentropy: 0.1095 - masked_loss: 0.1186 - sparse_categorical_accuracy: 0.9651 - val_loss: 2.4742 - val_sparse_categorical_crossentropy: 5.0632 - val_masked_loss: 5.4783 - val_sparse_categorical_accuracy: 0.4826
# Epoch 157/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0523 - sparse_categorical_crossentropy: 0.1076 - masked_loss: 0.1166 - sparse_categorical_accuracy: 0.9654 - val_loss: 2.4980 - val_sparse_categorical_crossentropy: 5.1119 - val_masked_loss: 5.5310 - val_sparse_categorical_accuracy: 0.4827
# Epoch 158/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0513 - sparse_categorical_crossentropy: 0.1060 - masked_loss: 0.1147 - sparse_categorical_accuracy: 0.9660 - val_loss: 2.4973 - val_sparse_categorical_crossentropy: 5.1105 - val_masked_loss: 5.5296 - val_sparse_categorical_accuracy: 0.4837
# Epoch 159/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0545 - sparse_categorical_crossentropy: 0.1137 - masked_loss: 0.1231 - sparse_categorical_accuracy: 0.9640 - val_loss: 2.4839 - val_sparse_categorical_crossentropy: 5.0830 - val_masked_loss: 5.4998 - val_sparse_categorical_accuracy: 0.4799
# Epoch 160/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0498 - sparse_categorical_crossentropy: 0.1024 - masked_loss: 0.1109 - sparse_categorical_accuracy: 0.9669 - val_loss: 2.4991 - val_sparse_categorical_crossentropy: 5.1141 - val_masked_loss: 5.5335 - val_sparse_categorical_accuracy: 0.4832
# Epoch 161/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0523 - sparse_categorical_crossentropy: 0.1077 - masked_loss: 0.1166 - sparse_categorical_accuracy: 0.9657 - val_loss: 2.5004 - val_sparse_categorical_crossentropy: 5.1168 - val_masked_loss: 5.5365 - val_sparse_categorical_accuracy: 0.4842
# Epoch 162/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0488 - sparse_categorical_crossentropy: 0.1017 - masked_loss: 0.1101 - sparse_categorical_accuracy: 0.9665 - val_loss: 2.5405 - val_sparse_categorical_crossentropy: 5.1989 - val_masked_loss: 5.6252 - val_sparse_categorical_accuracy: 0.4814
# Epoch 163/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0526 - sparse_categorical_crossentropy: 0.1062 - masked_loss: 0.1149 - sparse_categorical_accuracy: 0.9653 - val_loss: 2.5749 - val_sparse_categorical_crossentropy: 5.2694 - val_masked_loss: 5.7014 - val_sparse_categorical_accuracy: 0.4747
# Epoch 164/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0509 - sparse_categorical_crossentropy: 0.1035 - masked_loss: 0.1121 - sparse_categorical_accuracy: 0.9652 - val_loss: 2.5431 - val_sparse_categorical_crossentropy: 5.2042 - val_masked_loss: 5.6309 - val_sparse_categorical_accuracy: 0.4760
# Epoch 165/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0508 - sparse_categorical_crossentropy: 0.1032 - masked_loss: 0.1117 - sparse_categorical_accuracy: 0.9673 - val_loss: 2.5407 - val_sparse_categorical_crossentropy: 5.1993 - val_masked_loss: 5.6256 - val_sparse_categorical_accuracy: 0.4818
# Epoch 166/200
# 57/57 [==============================] - 6s 113ms/step - loss: 0.0474 - sparse_categorical_crossentropy: 0.0962 - masked_loss: 0.1041 - sparse_categorical_accuracy: 0.9692 - val_loss: 2.5425 - val_sparse_categorical_crossentropy: 5.2030 - val_masked_loss: 5.6297 - val_sparse_categorical_accuracy: 0.4787
# Epoch 167/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0485 - sparse_categorical_crossentropy: 0.0991 - masked_loss: 0.1073 - sparse_categorical_accuracy: 0.9687 - val_loss: 2.5824 - val_sparse_categorical_crossentropy: 5.2846 - val_masked_loss: 5.7179 - val_sparse_categorical_accuracy: 0.4816
# Epoch 168/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0491 - sparse_categorical_crossentropy: 0.1017 - masked_loss: 0.1101 - sparse_categorical_accuracy: 0.9677 - val_loss: 2.5900 - val_sparse_categorical_crossentropy: 5.3001 - val_masked_loss: 5.7346 - val_sparse_categorical_accuracy: 0.4803
# Epoch 169/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0461 - sparse_categorical_crossentropy: 0.0936 - masked_loss: 0.1013 - sparse_categorical_accuracy: 0.9708 - val_loss: 2.5564 - val_sparse_categorical_crossentropy: 5.2314 - val_masked_loss: 5.6604 - val_sparse_categorical_accuracy: 0.4828
# Epoch 170/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0471 - sparse_categorical_crossentropy: 0.0966 - masked_loss: 0.1046 - sparse_categorical_accuracy: 0.9689 - val_loss: 2.5854 - val_sparse_categorical_crossentropy: 5.2907 - val_masked_loss: 5.7246 - val_sparse_categorical_accuracy: 0.4794
# Epoch 171/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0470 - sparse_categorical_crossentropy: 0.0956 - masked_loss: 0.1036 - sparse_categorical_accuracy: 0.9687 - val_loss: 2.5802 - val_sparse_categorical_crossentropy: 5.2800 - val_masked_loss: 5.7130 - val_sparse_categorical_accuracy: 0.4754
# Epoch 172/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0469 - sparse_categorical_crossentropy: 0.0967 - masked_loss: 0.1046 - sparse_categorical_accuracy: 0.9691 - val_loss: 2.6363 - val_sparse_categorical_crossentropy: 5.3949 - val_masked_loss: 5.8373 - val_sparse_categorical_accuracy: 0.4761
# Epoch 173/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0447 - sparse_categorical_crossentropy: 0.0923 - masked_loss: 0.1000 - sparse_categorical_accuracy: 0.9709 - val_loss: 2.6117 - val_sparse_categorical_crossentropy: 5.3446 - val_masked_loss: 5.7829 - val_sparse_categorical_accuracy: 0.4789
# Epoch 174/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0443 - sparse_categorical_crossentropy: 0.0913 - masked_loss: 0.0989 - sparse_categorical_accuracy: 0.9709 - val_loss: 2.5858 - val_sparse_categorical_crossentropy: 5.2916 - val_masked_loss: 5.7255 - val_sparse_categorical_accuracy: 0.4812
# Epoch 175/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0434 - sparse_categorical_crossentropy: 0.0904 - masked_loss: 0.0978 - sparse_categorical_accuracy: 0.9709 - val_loss: 2.6744 - val_sparse_categorical_crossentropy: 5.4728 - val_masked_loss: 5.9215 - val_sparse_categorical_accuracy: 0.4688
# Epoch 176/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0490 - sparse_categorical_crossentropy: 0.1001 - masked_loss: 0.1083 - sparse_categorical_accuracy: 0.9687 - val_loss: 2.6422 - val_sparse_categorical_crossentropy: 5.4069 - val_masked_loss: 5.8503 - val_sparse_categorical_accuracy: 0.4760
# Epoch 177/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0462 - sparse_categorical_crossentropy: 0.0956 - masked_loss: 0.1034 - sparse_categorical_accuracy: 0.9687 - val_loss: 2.6197 - val_sparse_categorical_crossentropy: 5.3608 - val_masked_loss: 5.8003 - val_sparse_categorical_accuracy: 0.4756
# Epoch 178/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0451 - sparse_categorical_crossentropy: 0.0925 - masked_loss: 0.1001 - sparse_categorical_accuracy: 0.9704 - val_loss: 2.6457 - val_sparse_categorical_crossentropy: 5.4142 - val_masked_loss: 5.8582 - val_sparse_categorical_accuracy: 0.4714
# Epoch 179/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0434 - sparse_categorical_crossentropy: 0.0879 - masked_loss: 0.0952 - sparse_categorical_accuracy: 0.9716 - val_loss: 2.6099 - val_sparse_categorical_crossentropy: 5.3408 - val_masked_loss: 5.7787 - val_sparse_categorical_accuracy: 0.4789
# Epoch 180/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0419 - sparse_categorical_crossentropy: 0.0866 - masked_loss: 0.0937 - sparse_categorical_accuracy: 0.9717 - val_loss: 2.6388 - val_sparse_categorical_crossentropy: 5.4001 - val_masked_loss: 5.8429 - val_sparse_categorical_accuracy: 0.4718
# Epoch 181/200
# 57/57 [==============================] - 6s 109ms/step - loss: 0.0442 - sparse_categorical_crossentropy: 0.0887 - masked_loss: 0.0960 - sparse_categorical_accuracy: 0.9707 - val_loss: 2.6045 - val_sparse_categorical_crossentropy: 5.3298 - val_masked_loss: 5.7669 - val_sparse_categorical_accuracy: 0.4801
# Epoch 182/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0407 - sparse_categorical_crossentropy: 0.0833 - masked_loss: 0.0902 - sparse_categorical_accuracy: 0.9732 - val_loss: 2.5915 - val_sparse_categorical_crossentropy: 5.3032 - val_masked_loss: 5.7381 - val_sparse_categorical_accuracy: 0.4783
# Epoch 183/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0390 - sparse_categorical_crossentropy: 0.0803 - masked_loss: 0.0870 - sparse_categorical_accuracy: 0.9734 - val_loss: 2.6376 - val_sparse_categorical_crossentropy: 5.3975 - val_masked_loss: 5.8402 - val_sparse_categorical_accuracy: 0.4820
# Epoch 184/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0422 - sparse_categorical_crossentropy: 0.0871 - masked_loss: 0.0943 - sparse_categorical_accuracy: 0.9719 - val_loss: 2.6573 - val_sparse_categorical_crossentropy: 5.4379 - val_masked_loss: 5.8839 - val_sparse_categorical_accuracy: 0.4747
# Epoch 185/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0431 - sparse_categorical_crossentropy: 0.0884 - masked_loss: 0.0958 - sparse_categorical_accuracy: 0.9721 - val_loss: 2.6548 - val_sparse_categorical_crossentropy: 5.4328 - val_masked_loss: 5.8784 - val_sparse_categorical_accuracy: 0.4758
# Epoch 186/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0434 - sparse_categorical_crossentropy: 0.0885 - masked_loss: 0.0958 - sparse_categorical_accuracy: 0.9723 - val_loss: 2.6094 - val_sparse_categorical_crossentropy: 5.3399 - val_masked_loss: 5.7780 - val_sparse_categorical_accuracy: 0.4830
# Epoch 187/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0393 - sparse_categorical_crossentropy: 0.0810 - masked_loss: 0.0877 - sparse_categorical_accuracy: 0.9747 - val_loss: 2.6730 - val_sparse_categorical_crossentropy: 5.4701 - val_masked_loss: 5.9188 - val_sparse_categorical_accuracy: 0.4712
# Epoch 188/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0416 - sparse_categorical_crossentropy: 0.0852 - masked_loss: 0.0923 - sparse_categorical_accuracy: 0.9723 - val_loss: 2.6164 - val_sparse_categorical_crossentropy: 5.3541 - val_masked_loss: 5.7932 - val_sparse_categorical_accuracy: 0.4743
# Epoch 189/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0396 - sparse_categorical_crossentropy: 0.0807 - masked_loss: 0.0873 - sparse_categorical_accuracy: 0.9749 - val_loss: 2.6182 - val_sparse_categorical_crossentropy: 5.3579 - val_masked_loss: 5.7972 - val_sparse_categorical_accuracy: 0.4782
# Epoch 190/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0368 - sparse_categorical_crossentropy: 0.0756 - masked_loss: 0.0819 - sparse_categorical_accuracy: 0.9762 - val_loss: 2.6476 - val_sparse_categorical_crossentropy: 5.4181 - val_masked_loss: 5.8624 - val_sparse_categorical_accuracy: 0.4758
# Epoch 191/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0389 - sparse_categorical_crossentropy: 0.0809 - masked_loss: 0.0877 - sparse_categorical_accuracy: 0.9745 - val_loss: 2.6806 - val_sparse_categorical_crossentropy: 5.4855 - val_masked_loss: 5.9352 - val_sparse_categorical_accuracy: 0.4743
# Epoch 192/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0401 - sparse_categorical_crossentropy: 0.0820 - masked_loss: 0.0887 - sparse_categorical_accuracy: 0.9744 - val_loss: 2.6465 - val_sparse_categorical_crossentropy: 5.4158 - val_masked_loss: 5.8600 - val_sparse_categorical_accuracy: 0.4792
# Epoch 193/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0390 - sparse_categorical_crossentropy: 0.0800 - masked_loss: 0.0867 - sparse_categorical_accuracy: 0.9743 - val_loss: 2.7339 - val_sparse_categorical_crossentropy: 5.5946 - val_masked_loss: 6.0534 - val_sparse_categorical_accuracy: 0.4702
# Epoch 194/200
# 57/57 [==============================] - 10s 181ms/step - loss: 0.0385 - sparse_categorical_crossentropy: 0.0790 - masked_loss: 0.0855 - sparse_categorical_accuracy: 0.9748 - val_loss: 2.7174 - val_sparse_categorical_crossentropy: 5.5608 - val_masked_loss: 6.0167 - val_sparse_categorical_accuracy: 0.4739
# Epoch 195/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0363 - sparse_categorical_crossentropy: 0.0752 - masked_loss: 0.0814 - sparse_categorical_accuracy: 0.9761 - val_loss: 2.6975 - val_sparse_categorical_crossentropy: 5.5201 - val_masked_loss: 5.9727 - val_sparse_categorical_accuracy: 0.4769
# Epoch 196/200
# 57/57 [==============================] - 6s 109ms/step - loss: 0.0387 - sparse_categorical_crossentropy: 0.0796 - masked_loss: 0.0861 - sparse_categorical_accuracy: 0.9759 - val_loss: 2.7048 - val_sparse_categorical_crossentropy: 5.5351 - val_masked_loss: 5.9888 - val_sparse_categorical_accuracy: 0.4758
# Epoch 197/200
# 57/57 [==============================] - 6s 111ms/step - loss: 0.0382 - sparse_categorical_crossentropy: 0.0783 - masked_loss: 0.0847 - sparse_categorical_accuracy: 0.9756 - val_loss: 2.7320 - val_sparse_categorical_crossentropy: 5.5908 - val_masked_loss: 6.0492 - val_sparse_categorical_accuracy: 0.4708
# Epoch 198/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0381 - sparse_categorical_crossentropy: 0.0772 - masked_loss: 0.0836 - sparse_categorical_accuracy: 0.9756 - val_loss: 2.6823 - val_sparse_categorical_crossentropy: 5.4891 - val_masked_loss: 5.9392 - val_sparse_categorical_accuracy: 0.4790
# Epoch 199/200
# 57/57 [==============================] - 6s 112ms/step - loss: 0.0399 - sparse_categorical_crossentropy: 0.0821 - masked_loss: 0.0889 - sparse_categorical_accuracy: 0.9735 - val_loss: 2.7319 - val_sparse_categorical_crossentropy: 5.5906 - val_masked_loss: 6.0488 - val_sparse_categorical_accuracy: 0.4747
# Epoch 200/200
# 57/57 [==============================] - 6s 110ms/step - loss: 0.0361 - sparse_categorical_crossentropy: 0.0749 - masked_loss: 0.0810 - sparse_categorical_accuracy: 0.9762 - val_loss: 2.6823 - val_sparse_categorical_crossentropy: 5.4891 - val_masked_loss: 5.9391 - val_sparse_categorical_accuracy: 0.4773

# %% [markdown]
# Prediction

# %%
# Возьмем первые 10 значений данных
for i in range(10):
  translation = [tokenizer_all.vocab_size]

  # Пройдём по каждому токену (максимум 30) и сделаем предикт
  for _ in range(30):
    predict = model.predict([questions_batch[i:i+1],np.asarray([translation])]) # Делаем предикт
    translation.append(np.argmax(predict[-1,-1]))        # Ищем индекс токена
    if translation[-1] == tokenizer_all.vocab_size + 1:  # Если предсказан выходной тег, то заканчиваем цикл
      break
  
  # Запишем реальный ответ
  real_translation = []
  for w in answers_batch[:,1:][i].numpy():
    if w == tokenizer_all.vocab_size + 1:
      break
    real_translation.append(w)

  # Запишем вопрос
  real_text = []
  for w in questions_batch[:,1:][i].numpy():
    if w == tokenizer_all.vocab_size + 1:
      break
    real_text.append(w)
  
  print('Вопрос:             ', tokenizer_all.decode(real_text))
  print('Реальный ответ:     ', tokenizer_all.decode(real_translation))
  print('Ответ трансформера: ', tokenizer_all.decode(translation[1:-1]))
  print("")
# Out:
# Вопрос:              what year did the seahawks win the superbowl?
# Реальный ответ:      2006 NFL season
# Ответ трансформера:  1980 eruptielgh
#
# Вопрос:              who inspired obama?
# Реальный ответ:      Saul Alinsky
# Ответ трансформера:  Writer
#
# Вопрос:              who killed martin luther king jr video?
# Реальный ответ:      Assassination by firearm
# Ответ трансформера:  Charles I of Whines
#
# Вопрос:              where did charles darwin and his wife live?
# Реальный ответ:      Downe, Kent
# Ответ трансформера:  Tour Calims: Vigh
#
# Вопрос:              what happened at benghazi?
# Реальный ответ:      2012 U.S. diplomatic missions attacks
# Ответ трансформера:  Carl Philipp Eman
#
# Вопрос:              what was dr seuss education?
# Реальный ответ:      Dartmouth College
# Ответ трансформера:  Wadham College, Oxford
#
# Вопрос:              where does sherrod brown live?
# Реальный ответ:      Mansfield
# Ответ трансформера:  Shimbeh Walle
#
# Вопрос:              what was jesse owens education?
# Реальный ответ:      Ohio State University
# Ответ трансформера:  Wadham Celtio University
#
# Вопрос:              where does the shannon river start and end?
# Реальный ответ:      Shannon Pot
# Ответ трансформера:  Shannon Estuary
#
# Вопрос:              who plays king julian madagascar?
# Реальный ответ:      Sacha Baron Cohen
# Ответ трансформера:  Billy Millet

# %% [markdown]
# Ответы трансформера близкие по смыслу, но не точные. Данных достаточно мало, но результат не плохой.
